# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
import json
from collections import defaultdict

class WikipediaGraphScraper:
    def __init__(self):
        self.base_url = "https://vi.wikipedia.org/wiki/"
        self.session = requests.Session()
        self.session.headers.update({
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'
        })
        self.visited = set()
        self.nodes = {}
        self.edges = []

    def get_page(self, title):
        """Lấy nội dung HTML của một trang Wikipedia"""
        try:
            url = self.base_url + title.replace(" ", "_")
            response = self.session.get(url, timeout=10)
            response.encoding = 'utf-8'
            if response.status_code == 200:
                return BeautifulSoup(response.content, 'html.parser')
        except Exception as e:
            print(f"Lỗi khi truy cập {title}: {e}")
        return None

    def extract_infobox(self, soup):
        """Trích xuất thông tin từ infobox"""
        infobox = {}
        infobox_table = soup.find('table', {'class': 'infobox'})

        if infobox_table:
            rows = infobox_table.find_all('tr')
            for row in rows:
                cells = row.find_all(['th', 'td'])
                if len(cells) >= 2:
                    key = cells[0].get_text(strip=True)
                    value = cells[1].get_text(strip=True)
                    infobox[key] = value

        return infobox

    def extract_links(self, soup, title):
        """Trích xuất các liên kết từ trang Wikipedia"""
        links = []
        content = soup.find('div', {'id': 'mw-content-text'})

        if content:
            for link in content.find_all('a', href=True):
                href = link['href']
                # Chỉ lấy các link nội bộ Wikipedia
                if href.startswith('/wiki/'):
                    linked_title = href.replace('/wiki/', '').replace('_', ' ')
                    link_text = link.get_text(strip=True)

                    # Tránh các link đặc biệt
                    if not any(x in href for x in ['#', 'Special:', 'File:', 'Wikipedia:']):
                        links.append({
                            'target': linked_title,
                            'text': link_text,
                            'source': title
                        })

        return links

    def scrape_artist(self, artist_name, max_depth=2, current_depth=0):
        """Thu thập dữ liệu về một nghệ sĩ và các liên kết"""
        if artist_name in self.visited or current_depth > max_depth:
            return

        self.visited.add(artist_name)
        print(f"Đang xử lý: {artist_name} (Độ sâu: {current_depth})")

        soup = self.get_page(artist_name)
        if not soup:
            return

        # Trích xuất infobox
        infobox = self.extract_infobox(soup)

        # Tạo node
        self.nodes[artist_name] = {
            'type': 'artist',
            'infobox': infobox,
            'url': self.base_url + artist_name.replace(" ", "_")
        }

        # Trích xuất các liên kết
        links = self.extract_links(soup, artist_name)

        # Lọc các liên kết liên quan (album, bài hát, nghệ sĩ khác, v.v.)
        relevant_keywords = ['album', 'bài hát', 'ca sĩ', 'nhạc sĩ', 'nhóm nhạc',
                            'đơn ca', 'nhạc Hàn Quốc', 'K-pop', 'OST']

        for link in links[:30]:  # Giới hạn 30 liên kết per trang
            target = link['target']
            link_text = link['text']

            # Kiểm tra nếu là liên kết liên quan
            is_relevant = any(kw in link_text.lower() or kw in target.lower()
                             for kw in relevant_keywords)

            if is_relevant or current_depth < max_depth:
                # Tạo edge
                edge = {
                    'source': artist_name,
                    'target': target,
                    'relation': link_text,
                    'relation_type': 'related_to'
                }
                self.edges.append(edge)

                # Đệ quy thu thập dữ liệu
                if target not in self.visited:
                    self.scrape_artist(target, max_depth, current_depth + 1)

    def save_graph_data(self, filename='graph_data.json'):
        """Lưu dữ liệu graph"""
        data = {
            'nodes': self.nodes,
            'edges': self.edges,
            'statistics': {
                'total_nodes': len(self.nodes),
                'total_edges': len(self.edges)
            }
        }

        with open(filename, 'w', encoding='utf-8') as f:
            json.dump(data, f, ensure_ascii=False, indent=2)

        print(f"\nDữ liệu đã lưu vào {filename}")
        print(f"Tổng nodes: {len(self.nodes)}")
        print(f"Tổng edges: {len(self.edges)}")

    def print_node_info(self, node_name):
        """In thông tin chi tiết của một node"""
        if node_name in self.nodes:
            node = self.nodes[node_name]
            print(f"\n=== Node: {node_name} ===")
            print(f"URL: {node['url']}")
            print(f"\nInfobox:")
            for key, value in node['infobox'].items():
                print(f"  {key}: {value}")

            # In các liên kết
            print(f"\nCác liên kết từ node này:")
            related_edges = [e for e in self.edges if e['source'] == node_name]
            for edge in related_edges[:10]:
                print(f"  -> {edge['target']} ({edge['relation']})")
        else:
            print(f"Node '{node_name}' không được tìm thấy")


# Ví dụ sử dụng
if __name__ == "__main__":
    scraper = WikipediaGraphScraper()

    # Bắt đầu từ một ca sĩ/nhạc sĩ Hàn Quốc nổi tiếng
    start_artist = "BTS"  # Thay đổi theo ý muốn

    print(f"Bắt đầu thu thập dữ liệu từ: {start_artist}\n")
    scraper.scrape_artist(start_artist, max_depth=2)

    # In thông tin của node bắt đầu
    scraper.print_node_info(start_artist)

    # Lưu dữ liệu
    scraper.save_graph_data('korean_artists_graph.json')
# Out:
# Bắt đầu thu thập dữ liệu từ: BTS
#
# Đang xử lý: BTS (Độ sâu: 0)
# Đang xử lý: BTS (%C4%91%E1%BB%8Bnh h%C6%B0%E1%BB%9Bng) (Độ sâu: 1)
# Đang xử lý: Tr%E1%BA%A1m thu ph%C3%A1t s%C3%B3ng di %C4%91%E1%BB%99ng (Độ sâu: 2)
# Đang xử lý: X%C3%A2y d%E1%BB%B1ng d%E1%BB%B1 tr%E1%BB%AF (Độ sâu: 2)
# Đang xử lý: S%C3%A2n bay M. R. %C5%A0tef%C3%A1nik (Độ sâu: 2)
# Đang xử lý: %C4%90%E1%BA%B7c bi%E1%BB%87t:Ti%E1%BB%81n t%E1%BB%91/BTS (Độ sâu: 2)
# Đang xử lý: %C4%90%E1%BA%B7c bi%E1%BB%87t:T%C3%ACm ki%E1%BA%BFm/intitle:BTS (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:Disambig gray.svg (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:BTS during a White House press conference May 31, 2022 (cropped).jpg (Độ sâu: 1)
# Đang xử lý: Th%C3%A0nh vi%C3%AAn:Btspurplegalaxy (Độ sâu: 2)
# Đang xử lý: Danh s%C3%A1ch tweet c%C3%B3 nhi%E1%BB%81u l%C6%B0%E1%BB%A3t th%C3%ADch nh%E1%BA%A5t (Độ sâu: 2)
# Đang xử lý: %C4%90%E1%BA%B7c bi%E1%BB%87t:S%E1%BB%AD d%E1%BB%A5ng to%C3%A0n c%E1%BB%A5c/BTS during a White House press conference May 31, 2022 (cropped).jpg (Độ sâu: 2)
# Đang xử lý: Nh%C3%A0 Tr%E1%BA%AFng (Độ sâu: 1)
# Đang xử lý: T%E1%BA%ADp tin:White House north and south sides.jpg (Độ sâu: 2)
# Đang xử lý: Hoa K%E1%BB%B3 (Độ sâu: 2)
# Đang xử lý: Ki%E1%BA%BFn tr%C3%BAc s%C6%B0 (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:White House South Lawn.jpg (Độ sâu: 2)
# Đang xử lý: Nh%C3%A0 Tr%E1%BA%AFng (%C4%91%E1%BB%8Bnh h%C6%B0%E1%BB%9Bng) (Độ sâu: 2)
# Đang xử lý: Ti%E1%BA%BFng Anh (Độ sâu: 2)
# Đang xử lý: T%E1%BB%95ng th%E1%BB%91ng Hoa K%E1%BB%B3 (Độ sâu: 2)
# Đang xử lý: Tr%E1%BA%AFng (Độ sâu: 2)
# Đang xử lý: Sa th%E1%BA%A1ch (Độ sâu: 2)
# Đang xử lý: T%C3%A2n c%E1%BB%95 %C4%91i%E1%BB%83n (Độ sâu: 2)
# Đang xử lý: Washington, D.C. (Độ sâu: 2)
# Đang xử lý: Ho%C3%A1n d%E1%BB%A5 (Độ sâu: 2)
# Đang xử lý: %C4%90%C3%B4 la M%E1%BB%B9 (Độ sâu: 2)
# Đang xử lý: Qu%E1%BB%91c h%E1%BB%99i Hoa K%E1%BB%B3 (Độ sâu: 2)
# Đang xử lý: 16 th%C3%A1ng 7 (Độ sâu: 2)
# Đang xử lý: 1790 (Độ sâu: 2)
# Đang xử lý: George Washington (Độ sâu: 2)
# Đang xử lý: C%E1%BB%99ng h%C3%B2a Ireland (Độ sâu: 2)
# Đang xử lý: Vi%C3%AAn %C4%91%C3%A1 %C4%91%E1%BA%A7u ti%C3%AAn (Độ sâu: 2)
# Đang xử lý: 13 th%C3%A1ng 10 (Độ sâu: 2)
# Đang xử lý: 1792 (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:Whitehouse north.jpg (Độ sâu: 2)
# Đang xử lý: Nguy%C3%AAn th%E1%BB%A7 qu%E1%BB%91c gia (Độ sâu: 2)
# Đang xử lý: T%E1%BB%95ng th%E1%BB%91ng Ireland (Độ sâu: 2)
# Đang xử lý: Virginia (Độ sâu: 2)
# Đang xử lý: Seoul (Độ sâu: 1)
# Đang xử lý: Th%C3%A0nh ph%E1%BB%91 %C4%91%E1%BA%B7c bi%E1%BB%87t c%E1%BB%A7a H%C3%A0n Qu%E1%BB%91c (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:%EA%B2%BD%EB%B3%B5%EA%B6%81 %EA%B4%91%ED%99%94%EB%AC%B8 (cropped).jpg (Độ sâu: 2)
# Đang xử lý: Gwanghwamun (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:Teheran-ro Yeongdong-daero crossing 7.jpg (Độ sâu: 2)
# Đang xử lý: Trung t%C3%A2m h%E1%BB%99i ngh%E1%BB%8B v%C3%A0 tri%E1%BB%83n l%C3%A3m COEX (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:Seoul Olympic Stadium.jpg (Độ sâu: 2)
# Đang xử lý: S%C3%A2n v%E1%BA%ADn %C4%91%E1%BB%99ng Olympic Seoul (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:%EC%B0%BD%EB%8D%95%EA%B6%81 %EB%B6%80%EC%9A%A9%EC%A0%95 %EA%B7%BC%EA%B2%BD (2013).jpg (Độ sâu: 2)
# Đang xử lý: Changdeokgung (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:2018 Bukchon Hanok village.jpg (Độ sâu: 2)
# Đang xử lý: L%C3%A0ng Hanok Bukchon (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:Han River and Lotte World Tower.jpg (Độ sâu: 2)
# Đang xử lý: Lotte World Tower (Độ sâu: 2)
# Đang xử lý: S%C3%B4ng H%C3%A1n (Tri%E1%BB%81u Ti%C3%AAn) (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:Flag of Seoul.svg (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:Logo of Seoul, South Korea.svg (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:%EB%8F%99%ED%96%89%C2%B7%EB%A7%A4%EB%A0%A5 %ED%8A%B9%EB%B3%84%EC%8B%9C %EC%84%9C%EC%9A%B8.png (Độ sâu: 2)
# Đang xử lý: Kh%E1%BA%A9u hi%E1%BB%87u (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:Seoul in South Korea 2023.svg (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:South Korea physical map.svg (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:Asia laea relief location map.jpg (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:World location map (equirectangular 180).svg (Độ sâu: 2)
# Đang xử lý: Danh s%C3%A1ch qu%E1%BB%91c gia c%C3%B3 ch%E1%BB%A7 quy%E1%BB%81n (Độ sâu: 2)
# Đang xử lý: H%C3%A0n Qu%E1%BB%91c (Độ sâu: 2)
# Đang xử lý: V%C3%B9ng c%E1%BB%A7a Tri%E1%BB%81u Ti%C3%AAn (Độ sâu: 2)
# Đang xử lý: V%C3%B9ng th%E1%BB%A7 %C4%91%C3%B4 Seoul (Độ sâu: 2)
# Đang xử lý: Danh s%C3%A1ch qu%E1%BA%ADn c%E1%BB%A7a Seoul (Độ sâu: 2)
# Đang xử lý: Ch%C3%ADnh quy%E1%BB%81n th%E1%BB%8B tr%C6%B0%E1%BB%9Fng-h%E1%BB%99i %C4%91%E1%BB%93ng (Độ sâu: 2)
# Đang xử lý: Ch%C3%ADnh quy%E1%BB%81n Th%C3%A0nh ph%E1%BB%91 %C4%90%E1%BA%B7c bi%E1%BB%87t Seoul (Độ sâu: 2)
# Đang xử lý: K-pop (Độ sâu: 1)
# Đang xử lý: KPOP (%C4%91%E1%BB%8Bnh h%C6%B0%E1%BB%9Bng) (Độ sâu: 2)
# Đang xử lý: DPRK-pop (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:I love Kpop tattoo 04.png (Độ sâu: 2)
# Đang xử lý: %C3%82m nh%E1%BA%A1c Tri%E1%BB%81u Ti%C3%AAn (Độ sâu: 2)
# Đang xử lý: Experimental (nh%E1%BA%A1c) (Độ sâu: 2)
# Đang xử lý: Nh%E1%BA%A1c pop (Độ sâu: 2)
# Đang xử lý: Nh%E1%BA%A1c Ph%C3%BAc %C3%A2m (Độ sâu: 2)
# Đang xử lý: Nh%E1%BA%A1c Latinh (Độ sâu: 2)
# Đang xử lý: Rhythm and blues (Độ sâu: 2)
# Đang xử lý: Hip hop (Độ sâu: 2)
# Đang xử lý: Jazz (Độ sâu: 2)
# Đang xử lý: D%C3%A2n gian %C4%91%C6%B0%C6%A1ng %C4%91%E1%BA%A1i (Độ sâu: 2)
# Đang xử lý: Nh%E1%BA%A1c c%E1%BB%95 %C4%91i%E1%BB%83n (Độ sâu: 2)
# Đang xử lý: Nh%E1%BA%A1c %C4%91%E1%BB%93ng qu%C3%AA (Độ sâu: 2)
# Đang xử lý: Rock (Độ sâu: 2)
# Đang xử lý: Reggae (Độ sâu: 2)
# Đang xử lý: Nh%E1%BA%A1c dance %C4%91i%E1%BB%87n t%E1%BB%AD (Độ sâu: 2)
# Đang xử lý: Gi%E1%BB%8Dng h%C3%A1t (Độ sâu: 2)
# Đang xử lý: Tr%E1%BB%91ng %C4%91i%E1%BB%87n (Độ sâu: 2)
# Đang xử lý: Guitar bass (Độ sâu: 2)
# Đang xử lý: Synthesizer (Độ sâu: 2)
# Đang xử lý: Sampler (nh%E1%BA%A1c c%E1%BB%A5) (Độ sâu: 2)
# Đang xử lý: Digital audio workstation (Độ sâu: 2)
# Đang xử lý: Percussion (Độ sâu: 2)
# Đang xử lý: Incheon (Độ sâu: 2)
# Đang xử lý: Busan (Độ sâu: 2)
# Đang xử lý: Jeju (th%C3%A0nh ph%E1%BB%91) (Độ sâu: 2)
# Đang xử lý: Ti%E1%BA%BFng H%C3%A0n Qu%E1%BB%91c (Độ sâu: 2)
# Đang xử lý: Big Hit Music (Độ sâu: 1)
# Đang xử lý: Hybe Corporation (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:Big Hit Music Logo.svg (Độ sâu: 2)
# Đang xử lý: C%C3%B4ng ty con (Độ sâu: 2)
# Đang xử lý: Gi%E1%BA%A3i tr%C3%AD (Độ sâu: 2)
# Đang xử lý: Nh%E1%BA%A1c dance (Độ sâu: 2)
# Đang xử lý: Bang Si-hyuk (Độ sâu: 2)
# Đang xử lý: Yongsan-gu (Độ sâu: 2)
# Đang xử lý: C%C3%B4ng ty m%E1%BA%B9 (Độ sâu: 2)
# Đang xử lý: Website (Độ sâu: 2)
# Đang xử lý: C%C3%B4ng ty gi%E1%BA%A3i tr%C3%AD (Độ sâu: 2)
# Đang xử lý: Lee Hyun (Độ sâu: 2)
# Đang xử lý: Tomorrow X Together (Độ sâu: 2)
# Đang xử lý: 8Eight (Độ sâu: 2)
# Đang xử lý: 2AM (nh%C3%B3m nh%E1%BA%A1c) (Độ sâu: 2)
# Đang xử lý: Glam (nh%C3%B3m nh%E1%BA%A1c) (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:Big Hit Entertainment Logo black.svg (Độ sâu: 2)
# Đang xử lý: JYP Entertainment (Độ sâu: 2)
# Đang xử lý: Pony Canyon (Độ sâu: 1)
# Đang xử lý: T%E1%BA%ADp tin:Pony Canyon logo.svg (Độ sâu: 2)
# Đang xử lý: Kabushiki gaisha (Độ sâu: 2)
# Đang xử lý: Minato, Tokyo (Độ sâu: 2)
# Đang xử lý: S%E1%BA%A3n ph%E1%BA%A9m (Độ sâu: 2)
# Đang xử lý: Fuji Television (Độ sâu: 2)
# Đang xử lý: 1 th%C3%A1ng 10 (Độ sâu: 2)
# Đang xử lý: DVD (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp %C4%91o%C3%A0n truy%E1%BB%81n th%C3%B4ng (Độ sâu: 2)
# Đang xử lý: Nh%E1%BA%ADt B%E1%BA%A3n (Độ sâu: 2)
# Đang xử lý: M%C3%A1y t%C3%ADnh c%C3%A1 nh%C3%A2n (Độ sâu: 2)
# Đang xử lý: BBC (Độ sâu: 2)
# Đang xử lý: Columbia Pictures (Độ sâu: 2)
# Đang xử lý: Wayback Machine (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:Commons-logo.svg (Độ sâu: 2)
# Đang xử lý: B%E1%BA%A3n m%E1%BA%ABu:K-pop (Độ sâu: 2)
# Đang xử lý: Th%E1%BA%A3o lu%E1%BA%ADn B%E1%BA%A3n m%E1%BA%ABu:K-pop (Độ sâu: 2)
# Đang xử lý: %C4%90%E1%BA%B7c bi%E1%BB%87t:EditPage/B%E1%BA%A3n m%E1%BA%ABu:K-pop (Độ sâu: 2)
# Đang xử lý: L%C3%A0n s%C3%B3ng H%C3%A0n Qu%E1%BB%91c (Độ sâu: 2)
# Đang xử lý: Nh%E1%BA%A1c ballad H%C3%A0n Qu%E1%BB%91c (Độ sâu: 2)
# Đang xử lý: Trot (Độ sâu: 2)
# Đang xử lý: C%C3%B4ng ngh%E1%BB%87 v%C4%83n ho%C3%A1 (Độ sâu: 2)
# Đang xử lý: V%C3%B2ng hoa g%E1%BA%A1o (Độ sâu: 2)
# Đang xử lý: Th%E1%BA%A7n t%C6%B0%E1%BB%A3ng K-pop (Độ sâu: 2)
# Đang xử lý: Sasaeng fan (Độ sâu: 2)
# Đang xử lý: H%E1%BB%A3p %C4%91%E1%BB%93ng n%C3%B4 l%E1%BB%87 (Độ sâu: 2)
# Đang xử lý: Danh s%C3%A1ch ngh%E1%BB%87 s%C4%A9 K-pop ho%E1%BA%A1t %C4%91%E1%BB%99ng c%C3%A1 nh%C3%A2n (Độ sâu: 2)
# Đang xử lý: Def Jam Recordings (Độ sâu: 1)
# Đang xử lý: T%E1%BA%ADp tin:Def Jam Recordings.svg (Độ sâu: 2)
# Đang xử lý: Universal Music Group (Độ sâu: 2)
# Đang xử lý: Th%C3%A0nh ph%E1%BB%91 New York (Độ sâu: 2)
# Đang xử lý: H%C3%A3ng thu %C3%A2m (Độ sâu: 2)
# Đang xử lý: M%E1%BB%B9 (Độ sâu: 2)
# Đang xử lý: R%26B %C4%91%C6%B0%C6%A1ng %C4%91%E1%BA%A1i (Độ sâu: 2)
# Đang xử lý: Soul (Độ sâu: 2)
# Đang xử lý: Manhattan (Độ sâu: 2)
# Đang xử lý: V%C6%B0%C6%A1ng qu%E1%BB%91c Anh (Độ sâu: 2)
# Đang xử lý: Nam Phi (Độ sâu: 2)
# Đang xử lý: Nigeria (Độ sâu: 2)
# Đang xử lý: Rick Rubin (Độ sâu: 2)
# Đang xử lý: Punk rock (Độ sâu: 2)
# Đang xử lý: LL Cool J (Độ sâu: 2)
# Đang xử lý: Beastie Boys (Độ sâu: 2)
# Đang xử lý: R%26B (Độ sâu: 2)
# Đang xử lý: 8 th%C3%A1ng 12 (Độ sâu: 2)
# Đang xử lý: 2004 (Độ sâu: 2)
# Đang xử lý: 21 th%C3%A1ng 2 (Độ sâu: 2)
# Đang xử lý: 2020 (Độ sâu: 2)
# Đang xử lý: Ch%C3%A2u Phi (Độ sâu: 2)
# Đang xử lý: 29 th%C3%A1ng 8 (Độ sâu: 2)
# Đang xử lý: Columbia Records (Độ sâu: 1)
# Đang xử lý: T%E1%BA%ADp tin:Question book-new.svg (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:Columbia Records Colored Logo.svg (Độ sâu: 2)
# Đang xử lý: Sony Music Entertainment (Độ sâu: 2)
# Đang xử lý: Ti%E1%BB%83u bang New York (Độ sâu: 2)
# Đang xử lý: %C4%90%E1%BA%B7c bi%E1%BB%87t:Ngu%E1%BB%93n s%C3%A1ch/0811833941 (Độ sâu: 2)
# Đang xử lý: %C4%90%E1%BA%B7c bi%E1%BB%87t:Ngu%E1%BB%93n s%C3%A1ch/0937612103 (Độ sâu: 2)
# Đang xử lý: %C4%90%E1%BA%B7c bi%E1%BB%87t:Ngu%E1%BB%93n s%C3%A1ch/0316773336 (Độ sâu: 2)
# Đang xử lý: %C4%90%E1%BA%B7c bi%E1%BB%87t:Ngu%E1%BB%93n s%C3%A1ch/1560257075 (Độ sâu: 2)
# Đang xử lý: %C4%90%E1%BA%B7c bi%E1%BB%87t:Ngu%E1%BB%93n s%C3%A1ch/9780786868599 (Độ sâu: 2)
# Đang xử lý: Geffen Records (Độ sâu: 1)
# Đang xử lý: T%E1%BA%ADp tin:Geffen Records logo.svg (Độ sâu: 2)
# Đang xử lý: Polydor Records (Độ sâu: 2)
# Đang xử lý: Santa Monica, California (Độ sâu: 2)
# Đang xử lý: Decca Records (Độ sâu: 2)
# Đang xử lý: Elton John (Độ sâu: 2)
# Đang xử lý: Kylie Minogue (Độ sâu: 2)
# Đang xử lý: Enya (Độ sâu: 2)
# Đang xử lý: Cher (Độ sâu: 2)
# Đang xử lý: Guns N %27Roses (Độ sâu: 2)
# Đang xử lý: John Lennon (Độ sâu: 2)
# Đang xử lý: Joni Mitchell (Độ sâu: 2)
# Đang xử lý: Aerosmith (Độ sâu: 2)
# Đang xử lý: Neil Young (Độ sâu: 2)
# Đang xử lý: Peter Gabriel (Độ sâu: 2)
# Đang xử lý: Donna Summer (Độ sâu: 2)
# Đang xử lý: Nirvana (band) (Độ sâu: 2)
# Đang xử lý: Weezer (Độ sâu: 2)
# Đang xử lý: Mary J. Blige (Độ sâu: 2)
# Đang xử lý: Blink-182 (Độ sâu: 2)
# Đang xử lý: Avicii (Độ sâu: 2)
# Đang xử lý: DJ Snake (Độ sâu: 2)
# Đang xử lý: Beck (Độ sâu: 2)
# Đang xử lý: Nelly Furtado (Độ sâu: 2)
# Đang xử lý: Marshmello (Độ sâu: 2)
# Đang xử lý: Olivia Rodrigo (Độ sâu: 2)
# Đang xử lý: Snoop Dogg (Độ sâu: 2)
# Đang xử lý: Warner Bros. Pictures (Độ sâu: 2)
# Đang xử lý: Kim Seok-jin (Độ sâu: 1)
# Đang xử lý: T%E1%BA%ADp tin:Kim Seokjin at the White House, May 31, 2022.jpg (Độ sâu: 2)
# Đang xử lý: Gwacheon (Độ sâu: 2)
# Đang xử lý: Gyeonggi-do (Độ sâu: 2)
# Đang xử lý: %C4%90%E1%BA%A1i h%E1%BB%8Dc Konkuk (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:ROK Order of Cultural Merit Hwa-gwan (5th Class) ribbon.PNG (Độ sâu: 2)
# Đang xử lý: Hu%C3%A2n ch%C6%B0%C6%A1ng V%C4%83n h%C3%B3a (H%C3%A0n Qu%E1%BB%91c) (Độ sâu: 2)
# Đang xử lý: Pop-rock (Độ sâu: 2)
# Đang xử lý: Hangul (Độ sâu: 2)
# Đang xử lý: Hanja (Độ sâu: 2)
# Đang xử lý: Romaja qu%E1%BB%91c ng%E1%BB%AF (Độ sâu: 2)
# Đang xử lý: McCune%E2%80%93Reischauer (Độ sâu: 2)
# Đang xử lý: Phi%C3%AAn %C3%A2m H%C3%A1n-Vi%E1%BB%87t (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:Signature of BTS%27 Jin.svg (Độ sâu: 2)
# Đang xử lý: 4 th%C3%A1ng 12 (Độ sâu: 2)
# Đang xử lý: 1992 (Độ sâu: 2)
# Đang xử lý: Wings (album c%E1%BB%A7a BTS) (Độ sâu: 2)
# Đang xử lý: Epiphany (b%C3%A0i h%C3%A1t c%E1%BB%A7a BTS) (Độ sâu: 2)
# Đang xử lý: Map of the Soul: 7 (Độ sâu: 2)
# Đang xử lý: B%E1%BA%A3ng x%E1%BA%BFp h%E1%BA%A1ng nh%E1%BA%A1c s%E1%BB%91 Gaon (Độ sâu: 2)
# Đang xử lý: The Astronaut (b%C3%A0i h%C3%A1t c%E1%BB%A7a Jin) (Độ sâu: 2)
# Đang xử lý: T%E1%BB%95ng th%E1%BB%91ng H%C3%A0n Qu%E1%BB%91c (Độ sâu: 2)
# Đang xử lý: Kim Nam-gil (Độ sâu: 2)
# Đang xử lý: SM Entertainment (Độ sâu: 2)
# Đang xử lý: Suga (rapper) (Độ sâu: 1)
# Đang xử lý: T%C3%AAn ng%C6%B0%E1%BB%9Di Tri%E1%BB%81u Ti%C3%AAn (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:Suga for Marie Claire Korea, May 2023 issue 05.png (Độ sâu: 2)
# Đang xử lý: Daegu (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:Suga%27s signature.svg (Độ sâu: 2)
# Đang xử lý: 9 th%C3%A1ng 3 (Độ sâu: 2)
# Đang xử lý: 1993 (Độ sâu: 2)
# Đang xử lý: Mixtape (Độ sâu: 2)
# Đang xử lý: B%E1%BA%A3ng x%E1%BA%BFp h%E1%BA%A1ng Billboard (Độ sâu: 2)
# Đang xử lý: Billboard (Độ sâu: 2)
# Đang xử lý: Billboard 200 (Độ sâu: 2)
# Đang xử lý: UK Albums Chart (Độ sâu: 2)
# Đang xử lý: ARIA Charts (Độ sâu: 2)
# Đang xử lý: B%E1%BA%A3ng x%E1%BA%BFp h%E1%BA%A1ng %C3%82m nh%E1%BA%A1c Gaon (Độ sâu: 2)
# Đang xử lý: J-Hope (Độ sâu: 1)
# Đang xử lý: Tr%E1%BB%8Bnh (h%E1%BB%8D) (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:J-Hope at the 2022 Fact Music Awards on October 8, 2022 (cropped).jpg (Độ sâu: 2)
# Đang xử lý: Qu%E1%BA%ADn B%E1%BA%AFc, Gwangju (Độ sâu: 2)
# Đang xử lý: Gwangju (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:J-Hope signature.svg (Độ sâu: 2)
# Đang xử lý: 18 th%C3%A1ng 2 (Độ sâu: 2)
# Đang xử lý: 1994 (Độ sâu: 2)
# Đang xử lý: Becky G (Độ sâu: 2)
# Đang xử lý: Th%E1%BA%A7n t%C6%B0%E1%BB%A3ng H%C3%A0n Qu%E1%BB%91c (Độ sâu: 2)
# Đang xử lý: Chi%E1%BA%BFc h%E1%BB%99p Pandora (Độ sâu: 2)
# Đang xử lý: RM (rapper) (Độ sâu: 1)
# Đang xử lý: Kim (h%E1%BB%8D) (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:RM at W Korea Love Your W, November 2023.jpg (Độ sâu: 2)
# Đang xử lý: Dongjak-gu (Độ sâu: 2)
# Đang xử lý: Contemporary R%26B (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:RM signature.svg (Độ sâu: 2)
# Đang xử lý: RM (mixtape) (Độ sâu: 2)
# Đang xử lý: Mono (mixtape) (Độ sâu: 2)
# Đang xử lý: Younha (Độ sâu: 2)
# Đang xử lý: Fall Out Boy (Độ sâu: 2)
# Đang xử lý: Lil Nas X (Độ sâu: 2)
# Đang xử lý: Goyang (Độ sâu: 2)
# Đang xử lý: Nh%E1%BB%AFng ng%C6%B0%E1%BB%9Di b%E1%BA%A1n (Độ sâu: 2)
# Đang xử lý: Jimin (ca s%C4%A9, sinh 1995) (Độ sâu: 1)
# Đang xử lý: Jimin (%C4%91%E1%BB%8Bnh h%C6%B0%E1%BB%9Bng) (Độ sâu: 2)
# Đang xử lý: Ph%C3%A1c (h%E1%BB%8D) (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:Jimin on the way to SBS Radio, 31 March 2023 (2).jpg (Độ sâu: 2)
# Đang xử lý: Khu Geumjeong, Busan (Độ sâu: 2)
# Đang xử lý: Ca s%C4%A9 (Độ sâu: 2)
# Đang xử lý: Nh%E1%BA%A1c s%C4%A9 (Độ sâu: 2)
# Đang xử lý: V%C5%A9 c%C3%B4ng (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:Park Jimin Signature (BTS).svg (Độ sâu: 2)
# Đang xử lý: 1995 (Độ sâu: 2)
# Đang xử lý: Serendipity (b%C3%A0i h%C3%A1t c%E1%BB%A7a BTS) (Độ sâu: 2)
# Đang xử lý: Circle Digital Chart (Độ sâu: 2)
# Đang xử lý: Blues n%C6%A1i %C4%91%E1%BA%A3o xanh (Độ sâu: 2)
# Đang xử lý: TvN (k%C3%AAnh truy%E1%BB%81n h%C3%ACnh H%C3%A0n Qu%E1%BB%91c) (Độ sâu: 2)
# Đang xử lý: Ha Sung-woon (Độ sâu: 2)
# Đang xử lý: Billboard Hot 100 (Độ sâu: 2)
# Đang xử lý: V (ca s%C4%A9) (Độ sâu: 1)
# Đang xử lý: T%E1%BA%ADp tin:V in the Oval Office of the White House, May 31, 2022 (cropped).jpg (Độ sâu: 2)
# Đang xử lý: Rhythm and Blues (Độ sâu: 2)
# Đang xử lý: Neo soul (Độ sâu: 2)
# Đang xử lý: Indie pop (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:BTS%27 V Signature.svg (Độ sâu: 2)
# Đang xử lý: 30 th%C3%A1ng 12 (Độ sâu: 2)
# Đang xử lý: Geochang (Độ sâu: 2)
# Đang xử lý: Saxophone (Độ sâu: 2)
# Đang xử lý: Jungkook (Độ sâu: 1)
# Đang xử lý: T%E1%BA%ADp tin:Jeon Jungkook at the White House, 31 May 2022.jpg (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:Signature of BTS%27 Jungkook.svg (Độ sâu: 2)
# Đang xử lý: 1 th%C3%A1ng 9 (Độ sâu: 2)
# Đang xử lý: 1997 (Độ sâu: 2)
# Đang xử lý: G-Dragon (Độ sâu: 2)
# Đang xử lý: Superstar K (Độ sâu: 2)
# Đang xử lý: Big Hit Entertainment (Độ sâu: 2)
# Đang xử lý: Los Angeles (Độ sâu: 2)
# Đang xử lý: Jo Kwon (Độ sâu: 2)
# Đang xử lý: Kanji (Độ sâu: 1)
# Đang xử lý: Ti%E1%BA%BFng Nh%E1%BA%ADt (Độ sâu: 2)
# Đang xử lý: Ch%E1%BB%AF H%C3%A1n (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:Kanji furigana.svg (Độ sâu: 2)
# Đang xử lý: V%C4%83n t%E1%BB%B1 ng%E1%BB%AF t%E1%BB%91 (Độ sâu: 2)
# Đang xử lý: Ti%E1%BA%BFng Nh%E1%BA%ADt Th%C6%B0%E1%BB%A3ng %C4%91%E1%BA%A1i (Độ sâu: 2)
# Đang xử lý: Gi%C3%A1p c%E1%BB%91t v%C4%83n (Độ sâu: 2)
# Đang xử lý: Tri%E1%BB%87n th%C6%B0 (Độ sâu: 2)
# Đang xử lý: L%E1%BB%87 th%C6%B0 (Độ sâu: 2)
# Đang xử lý: Kh%E1%BA%A3i th%C6%B0 (Độ sâu: 2)
# Đang xử lý: Ch%C3%BA %C3%A2m ph%C3%B9 hi%E1%BB%87u (Độ sâu: 2)
# Đang xử lý: Ch%E1%BB%AF H%C3%A1n ph%E1%BB%93n th%E1%BB%83 (Độ sâu: 2)
# Đang xử lý: Ch%E1%BB%AF H%C3%A1n gi%E1%BA%A3n th%E1%BB%83 (Độ sâu: 2)
# Đang xử lý: Ch%E1%BB%AF N%C3%B4m (Độ sâu: 2)
# Đang xử lý: Ch%E1%BB%AF T%C3%A2y H%E1%BA%A1 (Độ sâu: 2)
# Đang xử lý: ISO 15924 (Độ sâu: 2)
# Đang xử lý: IPA (Độ sâu: 2)
# Đang xử lý: Unicode (Độ sâu: 2)
# Đang xử lý: Tr%E1%BB%A3 gi%C3%BAp:IPA (Độ sâu: 2)
# Đang xử lý: T%E1%BA%ADp tin:%E6%9B%B8.svg (Độ sâu: 2)
# Đang xử lý: H%E1%BB%87 th%E1%BB%91ng ch%E1%BB%AF vi%E1%BA%BFt ti%E1%BA%BFng Nh%E1%BA%ADt (Độ sâu: 2)
# Đang xử lý: Ky%C5%8Diku kanji (Độ sâu: 2)
# Đang xử lý: J%C5%8Dy%C5%8D kanji (Độ sâu: 2)
# Đang xử lý: Kana (Độ sâu: 2)
# Đang xử lý: Hiragana (Độ sâu: 2)
# Đang xử lý: Katakana (Độ sâu: 2)
# Đang xử lý: Hentaigana (Độ sâu: 2)
# Đang xử lý: Man%27y%C5%8Dgana (Độ sâu: 2)
# Đang xử lý: Sogana (Độ sâu: 2)
# Đang xử lý: H%E1%BB%87 phi%C3%AAn %C3%A2m La-tinh Hepburn (Độ sâu: 1)
# Đang xử lý: Tr%E1%BB%A3 gi%C3%BAp:Ti%E1%BA%BFng Nh%E1%BA%ADt (Độ sâu: 2)
# Đang xử lý: James Curtis Hepburn (Độ sâu: 2)
# Đang xử lý: B%E1%BA%A3ng ch%E1%BB%AF c%C3%A1i Latinh (Độ sâu: 2)
# Đang xử lý: Furigana (Độ sâu: 2)
# Đang xử lý: Okurigana (Độ sâu: 2)
# Đang xử lý: R%C5%8Dmaji (Độ sâu: 2)
# Đang xử lý: B%E1%BA%A3n m%E1%BA%ABu:H%E1%BB%87 th%E1%BB%91ng ch%E1%BB%AF vi%E1%BA%BFt ti%E1%BA%BFng Nh%E1%BA%ADt (Độ sâu: 2)
# Đang xử lý: %C4%90%E1%BA%B7c bi%E1%BB%87t:EditPage/B%E1%BA%A3n m%E1%BA%ABu:H%E1%BB%87 th%E1%BB%91ng ch%E1%BB%AF vi%E1%BA%BFt ti%E1%BA%BFng Nh%E1%BA%ADt (Độ sâu: 2)
# Đang xử lý: N%E1%BB%99i c%C3%A1c (Độ sâu: 2)
# Đang xử lý: Chi%E1%BA%BFm %C4%91%C3%B3ng Nh%E1%BA%ADt B%E1%BA%A3n (Độ sâu: 2)
# Đang xử lý: Oxford University Press (Độ sâu: 2)
# Đang xử lý: S%E1%BA%AFn d%C3%A2y (Độ sâu: 2)
# Đang xử lý: Ch%C3%ADnh t%E1%BA%A3 (Độ sâu: 2)
# Đang xử lý: %C3%82m v%E1%BB%8B h%E1%BB%8Dc (Độ sâu: 2)
# Đang xử lý: Sokuon (Độ sâu: 2)
# Đang xử lý: Matcha (Độ sâu: 2)
#
# === Node: BTS ===
# URL: https://vi.wikipedia.org/wiki/BTS
#
# Infobox:
#   Tên gọi khác: Bangtan BoysBangtan SonyeondanBeyond the SceneBulletproof Boy Scouts
#   Nguyên quán: Seoul,Hàn Quốc
#   Thể loại: K-poppophip hopR&BEDM
#   Năm hoạt động: 2013(2013)–nay
#   Hãng đĩa: Big HitPony CanyonDef Jam Japan[1]ColumbiaUniversalGeffen
#   Thành viên: JinSugaJ-HopeRMJiminVJungkook
#   Website: bts.ibighit.com
#   Hangul: 방탄소년단
#   Hanja: 防彈少年團
#   Phiên âmRomaja quốc ngữBangtan SonyeondanMcCune–ReischauerPangt'an Sonyǒndan: Phiên âm
#   Romaja quốc ngữ: Bangtan Sonyeondan
#   McCune–Reischauer: Pangt'an Sonyǒndan
#   Kanji: 防弾少年団
#   Hiragana: ぼうだんしょうねんだん
#   Chuyển tựHepburnBōdan ShōnendanKunrei-shikiBôdan Syônendan: Chuyển tự
#   Hepburn: Bōdan Shōnendan
#   Kunrei-shiki: Bôdan Syônendan
#
# Các liên kết từ node này:
#   -> BTS (%C4%91%E1%BB%8Bnh h%C6%B0%E1%BB%9Bng) (BTS (định hướng))
#   -> T%E1%BA%ADp tin:BTS during a White House press conference May 31, 2022 (cropped).jpg ()
#   -> Nh%C3%A0 Tr%E1%BA%AFng (Nhà Trắng)
#   -> Seoul (Seoul)
#   -> H%C3%A0n Qu%E1%BB%91c (Hàn Quốc)
#   -> K-pop (K-pop)
#   -> Nh%E1%BA%A1c pop (pop)
#   -> Hip hop (hip hop)
#   -> Rhythm and blues (R&B)
#   -> Nh%E1%BA%A1c dance %C4%91i%E1%BB%87n t%E1%BB%AD (EDM)
#
# Dữ liệu đã lưu vào korean_artists_graph.json
# Tổng nodes: 346
# Tổng edges: 675

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urlparse
import json
from collections import defaultdict, deque
import time

class WikipediaGraphScraper:
    def __init__(self):
        self.base_url = "https://vi.wikipedia.org/wiki/"
        self.session = requests.Session()
        self.session.headers.update({
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'
        })
        self.visited = set()
        self.nodes = {}
        self.edges = []
        self.artist_keywords = ['ca sĩ', 'nhạc sĩ', 'diễn viên', 'nhóm nhạc', 'K-pop',
                               'album', 'bài hát', 'OST', 'giải thưởng']

    def get_page(self, title):
        """Lấy nội dung HTML của một trang Wikipedia"""
        try:
            url = self.base_url + title.replace(" ", "_")
            response = self.session.get(url, timeout=10)
            response.encoding = 'utf-8'
            if response.status_code == 200:
                return BeautifulSoup(response.content, 'html.parser')
        except Exception as e:
            print(f"Lỗi khi truy cập {title}: {e}")
        return None

    def extract_infobox(self, soup):
        """Trích xuất thông tin từ infobox"""
        infobox = {}
        infobox_table = soup.find('table', {'class': 'infobox'})

        if infobox_table:
            rows = infobox_table.find_all('tr')
            for row in rows:
                cells = row.find_all(['th', 'td'])
                if len(cells) >= 2:
                    key = cells[0].get_text(strip=True)
                    value = cells[1].get_text(strip=True)
                    infobox[key] = value

        return infobox

    def extract_links(self, soup, title):
        """Trích xuất các liên kết từ trang Wikipedia"""
        links = []
        content = soup.find('div', {'id': 'mw-content-text'})

        if content:
            for link in content.find_all('a', href=True):
                href = link['href']
                if href.startswith('/wiki/'):
                    linked_title = href.replace('/wiki/', '').replace('_', ' ')
                    link_text = link.get_text(strip=True)

                    if not any(x in href for x in ['#', 'Special:', 'File:', 'Wikipedia:']):
                        links.append({
                            'target': linked_title,
                            'text': link_text,
                            'source': title
                        })

        return links

    def is_artist_related(self, text):
        """Kiểm tra xem một liên kết có liên quan đến ca sĩ/nhạc sĩ"""
        text_lower = text.lower()
        return any(kw in text_lower for kw in self.artist_keywords)

    def calculate_relevance_score(self, node_name, infobox, links):
        """Tính điểm liên quan của một node"""
        score = 0

        # Kiểm tra trong tên
        if any(kw in node_name.lower() for kw in ['ca sĩ', 'nhạc sĩ', 'K-pop']):
            score += 10

        # Kiểm tra trong infobox
        infobox_text = ' '.join(infobox.values()).lower()
        if 'ca sĩ' in infobox_text or 'nhạc sĩ' in infobox_text or 'K-pop' in infobox_text:
            score += 8

        # Đếm liên kết liên quan
        artist_links = sum(1 for link in links if self.is_artist_related(link['text']))
        score += min(artist_links, 10)

        return score

    # ============= CÁC THUẬT TOÁN DUYỆT =============

    def bfs_expansion(self, seed_artists, max_nodes=1000, max_links_per_node=15):
        """
        Thuật toán BFS (Breadth-First Search)
        - Duyệt theo tầng
        - Đảm bảo phát hiện tất cả các node gần với hạt giống
        - Phù hợp với mạng rộng, nông
        """
        print("\n" + "="*70)
        print("THUẬT TOÁN: BFS (Breadth-First Search)")
        print("="*70)

        queue = deque([(artist, 0) for artist in seed_artists])
        self.visited = set(seed_artists)
        level_stats = defaultdict(int)

        while queue and len(self.nodes) < max_nodes:
            current_node, depth = queue.popleft()
            level_stats[depth] += 1

            print(f"[BFS Tầng {depth}] Xử lý: {current_node}")

            soup = self.get_page(current_node)
            if not soup:
                continue

            infobox = self.extract_infobox(soup)
            self.nodes[current_node] = {
                'type': 'artist',
                'infobox': infobox,
                'url': self.base_url + current_node.replace(" ", "_"),
                'depth': depth
            }

            links = self.extract_links(soup, current_node)
            artist_links = [l for l in links if self.is_artist_related(l['text'])][:max_links_per_node]

            for link in artist_links:
                target = link['target']
                if target not in self.visited and len(self.nodes) < max_nodes:
                    self.visited.add(target)
                    queue.append((target, depth + 1))

                    self.edges.append({
                        'source': current_node,
                        'target': target,
                        'relation': link['text'],
                        'relation_type': 'related_to'
                    })

            time.sleep(0.5)

        print(f"\nThống kê BFS theo tầng: {dict(level_stats)}")
        return self.nodes, self.edges

    def dfs_expansion(self, seed_artists, max_nodes=1000, max_depth=3, max_links_per_node=10):
        """
        Thuật toán DFS (Depth-First Search)
        - Duyệt theo chiều sâu
        - Phát hiện các chuỗi liên kết dài
        - Phù hợp với mạng có cấu trúc phân nhánh
        """
        print("\n" + "="*70)
        print("THUẬT TOÁN: DFS (Depth-First Search)")
        print("="*70)

        self.visited = set()
        depth_stats = defaultdict(int)

        def dfs_helper(node, depth):
            if len(self.nodes) >= max_nodes or depth > max_depth or node in self.visited:
                return

            self.visited.add(node)
            depth_stats[depth] += 1

            print(f"[DFS Độ sâu {depth}] Xử lý: {node}")

            soup = self.get_page(node)
            if not soup:
                return

            infobox = self.extract_infobox(soup)
            self.nodes[node] = {
                'type': 'artist',
                'infobox': infobox,
                'url': self.base_url + node.replace(" ", "_"),
                'depth': depth
            }

            links = self.extract_links(soup, node)
            artist_links = [l for l in links if self.is_artist_related(l['text'])][:max_links_per_node]

            for link in artist_links:
                target = link['target']
                self.edges.append({
                    'source': node,
                    'target': target,
                    'relation': link['text'],
                    'relation_type': 'related_to'
                })
                dfs_helper(target, depth + 1)

            time.sleep(0.3)

        for seed in seed_artists:
            dfs_helper(seed, 0)

        print(f"\nThống kê DFS theo độ sâu: {dict(depth_stats)}")
        return self.nodes, self.edges

    def priority_expansion(self, seed_artists, max_nodes=1000, max_links_per_node=15):
        """
        Thuật toán Priority-based Expansion
        - Duyệt ưu tiên theo điểm liên quan
        - Sử dụng heuristic để ưu tiên các node quan trọng
        - Phù hợp với mạng có độ dày khác nhau
        """
        print("\n" + "="*70)
        print("THUẬT TOÁN: Priority-based Expansion")
        print("="*70)

        from heapq import heappush, heappop

        priority_queue = []
        self.visited = set()

        # Khởi tạo với hạt giống
        for seed in seed_artists:
            heappush(priority_queue, (-100, seed, 0))  # Ưu tiên cao nhất

        stats = {
            'high_priority': 0,
            'medium_priority': 0,
            'low_priority': 0
        }

        while priority_queue and len(self.nodes) < max_nodes:
            priority, current_node, depth = heappop(priority_queue)
            priority = -priority

            if current_node in self.visited:
                continue

            self.visited.add(current_node)

            print(f"[Priority {priority}] Xử lý: {current_node}")

            soup = self.get_page(current_node)
            if not soup:
                continue

            infobox = self.extract_infobox(soup)
            links = self.extract_links(soup, current_node)

            # Tính điểm liên quan
            relevance = self.calculate_relevance_score(current_node, infobox, links)

            self.nodes[current_node] = {
                'type': 'artist',
                'infobox': infobox,
                'url': self.base_url + current_node.replace(" ", "_"),
                'depth': depth,
                'relevance_score': relevance
            }

            artist_links = [l for l in links if self.is_artist_related(l['text'])][:max_links_per_node]

            for link in artist_links:
                target = link['target']
                if target not in self.visited and len(self.nodes) < max_nodes:
                    # Tính điểm cho node tiếp theo
                    next_relevance = max(0, relevance - 2)  # Giảm dần

                    if next_relevance > 15:
                        stats['high_priority'] += 1
                    elif next_relevance > 8:
                        stats['medium_priority'] += 1
                    else:
                        stats['low_priority'] += 1

                    heappush(priority_queue, (-next_relevance, target, depth + 1))

                    self.edges.append({
                        'source': current_node,
                        'target': target,
                        'relation': link['text'],
                        'relation_type': 'related_to',
                        'relevance_score': next_relevance
                    })

            time.sleep(0.5)

        print(f"\nThống kê Priority: {stats}")
        return self.nodes, self.edges

    def save_graph_data(self, filename='graph_data.json'):
        """Lưu dữ liệu graph"""
        data = {
            'nodes': self.nodes,
            'edges': self.edges,
            'statistics': {
                'total_nodes': len(self.nodes),
                'total_edges': len(self.edges)
            }
        }

        with open(filename, 'w', encoding='utf-8') as f:
            json.dump(data, f, ensure_ascii=False, indent=2)

        print(f"\nDữ liệu đã lưu vào {filename}")
        print(f"Tổng nodes: {len(self.nodes)}")
        print(f"Tổng edges: {len(self.edges)}")

    def print_summary(self):
        """In tóm tắt mạng lưới"""
        print("\n" + "="*70)
        print("TÓM TẮT MẠNG LƯỚI")
        print("="*70)
        print(f"Tổng nodes: {len(self.nodes)}")
        print(f"Tổng edges: {len(self.edges)}")
        print(f"Mật độ: {len(self.edges) / max(1, len(self.nodes)):.2f}")

        # Node có liên kết nhiều nhất
        edge_count = defaultdict(int)
        for edge in self.edges:
            edge_count[edge['source']] += 1

        if edge_count:
            top_nodes = sorted(edge_count.items(), key=lambda x: x[1], reverse=True)[:5]
            print("\nTop 5 node có liên kết nhiều nhất:")
            for node, count in top_nodes:
                print(f"  - {node}: {count} liên kết")


# Tập hạt giống
SEED_ARTISTS = [
    "BTS", "BLACKPINK", "TWICE", "IU", "EXO"
]


# Ví dụ sử dụng
if __name__ == "__main__":
    print("="*70)
    print("HỆ THỐNG DUYỆT TẬP HẠT GIỐNG - CA SĨ/NHẠC Sĩ HÀN QUỐC")
    print("="*70)
    print(f"\nTập hạt giống: {SEED_ARTISTS}")
    print(f"Số lượng hạt giống: {len(SEED_ARTISTS)}\n")

    # Chọn thuật toán
    print("Chọn thuật toán duyệt:")
    print("1. BFS - Breadth-First Search")
    print("2. DFS - Depth-First Search")
    print("3. Priority-based Expansion")

    choice = input("\nNhập lựa chọn (1/2/3): ").strip()

    scraper = WikipediaGraphScraper()

    if choice == "1":
        scraper.bfs_expansion(SEED_ARTISTS, max_nodes=100, max_links_per_node=15)
    elif choice == "2":
        scraper.dfs_expansion(SEED_ARTISTS, max_nodes=100, max_depth=3, max_links_per_node=10)
    elif choice == "3":
        scraper.priority_expansion(SEED_ARTISTS, max_nodes=100, max_links_per_node=15)
    else:
        print("Lựa chọn không hợp lệ, sử dụng BFS mặc định")
        scraper.bfs_expansion(SEED_ARTISTS, max_nodes=100)

    scraper.print_summary()
    scraper.save_graph_data(f'korean_artists_graph_{choice}.json')
# Out:
# ======================================================================
# HỆ THỐNG DUYỆT TẬP HẠT GIỐNG - CA SĨ/NHẠC Sĩ HÀN QUỐC
# ======================================================================
#
# Tập hạt giống: ['BTS', 'BLACKPINK', 'TWICE', 'IU', 'EXO']
# Số lượng hạt giống: 5
#
# Chọn thuật toán duyệt:
# 1. BFS - Breadth-First Search
# 2. DFS - Depth-First Search
# 3. Priority-based Expansion
#
# Nhập lựa chọn (1/2/3): 2
#
# ======================================================================
# THUẬT TOÁN: DFS (Depth-First Search)
# ======================================================================
# [DFS Độ sâu 0] Xử lý: BTS
# [DFS Độ sâu 1] Xử lý: Nh%C3%B3m nh%E1%BA%A1c nam
# [DFS Độ sâu 2] Xử lý: Nh%C3%B3m nh%E1%BA%A1c n%E1%BB%AF
# [DFS Độ sâu 3] Xử lý: Ban nh%E1%BA%A1c
# [DFS Độ sâu 3] Xử lý: AKB48 Group
# [DFS Độ sâu 3] Xử lý: Gaon Album Chart
# [DFS Độ sâu 3] Xử lý: Danh s%C3%A1ch nh%C3%B3m nh%E1%BA%A1c n%E1%BB%AF H%C3%A0n Qu%E1%BB%91c
# [DFS Độ sâu 3] Xử lý: Album ch%E1%BB%A7 %C4%91%E1%BB%81
# [DFS Độ sâu 3] Xử lý: Nh%C3%B3m nh%E1%BA%A1c
# [DFS Độ sâu 2] Xử lý: Si%C3%AAu ban nh%E1%BA%A1c
# [DFS Độ sâu 2] Xử lý: Danh s%C3%A1ch album b%C3%A1n ch%E1%BA%A1y nh%E1%BA%A5t t%E1%BA%A1i H%C3%A0n Qu%E1%BB%91c
# [DFS Độ sâu 3] Xử lý: Danh s%C3%A1ch album %C4%91%E1%BA%A1t ch%E1%BB%A9ng nh%E1%BA%ADn t%E1%BA%A1i H%C3%A0n Qu%E1%BB%91c
# [DFS Độ sâu 3] Xử lý: The Album
# [DFS Độ sâu 3] Xử lý: The Bodyguard: Original Soundtrack Album
# [DFS Độ sâu 3] Xử lý: Circle Album Chart
# [DFS Độ sâu 3] Xử lý: Danh s%C3%A1ch b%C3%A0i h%C3%A1t %C4%91%E1%BA%A1t ch%E1%BB%A9ng nh%E1%BA%ADn t%E1%BA%A1i H%C3%A0n Qu%E1%BB%91c
# [DFS Độ sâu 2] Xử lý: Album ph%C3%B2ng thu
# [DFS Độ sâu 3] Xử lý: Album hay nh%E1%BA%A5t n%C4%83m c%E1%BB%A7a NME
# [DFS Độ sâu 1] Xử lý: Danh s%C3%A1ch gi%E1%BA%A3i th%C6%B0%E1%BB%9Fng v%C3%A0 %C4%91%E1%BB%81 c%E1%BB%AD c%E1%BB%A7a BTS
# [DFS Độ sâu 2] Xử lý: %C4%90%C4%A9a %C4%91%C6%A1n
# [DFS Độ sâu 3] Xử lý: B%C3%A0i h%C3%A1t
# [DFS Độ sâu 3] Xử lý: Album
# [DFS Độ sâu 3] Xử lý: Nh%E1%BA%A1c s%C4%A9
# [DFS Độ sâu 3] Xử lý: %C4%90%C4%A9a m%E1%BB%9F r%E1%BB%99ng
# [DFS Độ sâu 2] Xử lý: Album t%E1%BB%95ng h%E1%BB%A3p
# [DFS Độ sâu 3] Xử lý: Demo (nh%E1%BA%A1c)
# [DFS Độ sâu 3] Xử lý: Album tuy%E1%BB%83n t%E1%BA%ADp
# [DFS Độ sâu 2] Xử lý: Album t%C3%A1i ph%C3%A1t h%C3%A0nh
# [DFS Độ sâu 2] Xử lý: Gi%E1%BA%A3i th%C6%B0%E1%BB%9Fng %C3%82m nh%E1%BA%A1c M%E1%BB%B9 cho Ban nh%E1%BA%A1c/C%E1%BA%B7p %C4%91%C3%B4i/Nh%C3%B3m nh%E1%BA%A1c Pop/Rock %C4%91%C6%B0%E1%BB%A3c y%C3%AAu th%C3%ADch nh%E1%BA%A5t
# [DFS Độ sâu 3] Xử lý: Gi%E1%BA%A3i th%C6%B0%E1%BB%9Fng %C3%82m nh%E1%BA%A1c M%E1%BB%B9
# [DFS Độ sâu 3] Xử lý: Gi%E1%BA%A3i th%C6%B0%E1%BB%9Fng %C3%82m nh%E1%BA%A1c M%E1%BB%B9 cho Ngh%E1%BB%87 s%C4%A9 c%E1%BB%A7a n%C4%83m
# [DFS Độ sâu 3] Xử lý: Gi%E1%BA%A3i th%C6%B0%E1%BB%9Fng %C3%82m nh%E1%BA%A1c M%E1%BB%B9 cho Album Pop/Rock %C4%91%C6%B0%E1%BB%A3c y%C3%AAu th%C3%ADch nh%E1%BA%A5t
# [DFS Độ sâu 3] Xử lý: Gi%E1%BA%A3i th%C6%B0%E1%BB%9Fng %C3%82m nh%E1%BA%A1c M%E1%BB%B9 cho Ban nh%E1%BA%A1c/C%E1%BA%B7p %C4%91%C3%B4i/Nh%C3%B3m nh%E1%BA%A1c %C4%90%E1%BB%93ng qu%C3%AA %C4%91%C6%B0%E1%BB%A3c y%C3%AAu th%C3%ADch nh%E1%BA%A5t
# [DFS Độ sâu 3] Xử lý: Gi%E1%BA%A3i th%C6%B0%E1%BB%9Fng %C3%82m nh%E1%BA%A1c M%E1%BB%B9 cho Album %C4%90%E1%BB%93ng qu%C3%AA %C4%91%C6%B0%E1%BB%A3c y%C3%AAu th%C3%ADch nh%E1%BA%A5t
# [DFS Độ sâu 2] Xử lý: Gi%E1%BA%A3i Grammy cho Tr%C3%ACnh di%E1%BB%85n song t%E1%BA%A5u ho%E1%BA%B7c nh%C3%B3m nh%E1%BA%A1c pop xu%E1%BA%A5t s%E1%BA%AFc nh%E1%BA%A5t
# [DFS Độ sâu 3] Xử lý: Gi%E1%BA%A3i Grammy cho Tr%C3%ACnh di%E1%BB%85n song t%E1%BA%A5u ho%E1%BA%B7c nh%C3%B3m nh%E1%BA%A1c gi%E1%BB%8Dng pop xu%E1%BA%A5t s%E1%BA%AFc nh%E1%BA%A5t
# [DFS Độ sâu 3] Xử lý: Gi%E1%BA%A3i Grammy cho Tr%C3%ACnh di%E1%BB%85n song t%E1%BA%A5u ho%E1%BA%B7c nh%C3%B3m nh%E1%BA%A1c gi%E1%BB%8Dng rock xu%E1%BA%A5t s%E1%BA%AFc nh%E1%BA%A5t
# [DFS Độ sâu 3] Xử lý: Gi%E1%BA%A3i Grammy cho album c%E1%BB%A7a n%C4%83m
# [DFS Độ sâu 3] Xử lý: Gi%E1%BA%A3i Grammy cho b%C3%A0i h%C3%A1t c%E1%BB%A7a n%C4%83m
# [DFS Độ sâu 3] Xử lý: Gi%E1%BA%A3i Grammy cho album soundtrack nh%E1%BA%A1c n%E1%BB%81n xu%E1%BA%A5t s%E1%BA%AFc nh%E1%BA%A5t cho ph%C6%B0%C6%A1ng ti%E1%BB%87n truy%E1%BB%81n h%C3%ACnh %E1%BA%A3nh
# [DFS Độ sâu 3] Xử lý: Gi%E1%BA%A3i Grammy cho album soundtrack tuy%E1%BB%83n t%E1%BA%ADp xu%E1%BA%A5t s%E1%BA%AFc nh%E1%BA%A5t cho ph%C6%B0%C6%A1ng ti%E1%BB%87n truy%E1%BB%81n h%C3%ACnh %E1%BA%A3nh
# [DFS Độ sâu 3] Xử lý: Gi%E1%BA%A3i Grammy cho b%C3%A0i h%C3%A1t xu%E1%BA%A5t s%E1%BA%AFc nh%E1%BA%A5t %C4%91%C6%B0%E1%BB%A3c s%C3%A1ng t%C3%A1c cho ph%C6%B0%C6%A1ng ti%E1%BB%87n truy%E1%BB%81n h%C3%ACnh %E1%BA%A3nh
# [DFS Độ sâu 3] Xử lý: Gi%E1%BA%A3i Grammy cho album latin pop xu%E1%BA%A5t s%E1%BA%AFc nh%E1%BA%A5t
# [DFS Độ sâu 3] Xử lý: Gi%E1%BA%A3i Grammy cho album gi%E1%BB%8Dng pop xu%E1%BA%A5t s%E1%BA%AFc nh%E1%BA%A5t
# [DFS Độ sâu 3] Xử lý: Gi%E1%BA%A3i Grammy cho album nh%E1%BA%A1c dance/%C4%91i%E1%BB%87n t%E1%BB%AD xu%E1%BA%A5t s%E1%BA%AFc nh%E1%BA%A5t
# [DFS Độ sâu 2] Xử lý: Danh s%C3%A1ch album c%E1%BB%A7a BTS
# [DFS Độ sâu 3] Xử lý: Oricon Albums Chart
# [DFS Độ sâu 3] Xử lý: %C4%90%C6%A1n v%E1%BB%8B album t%C6%B0%C6%A1ng %C4%91%C6%B0%C6%A1ng
# [DFS Độ sâu 1] Xử lý: UK Albums Chart
# [DFS Độ sâu 0] Xử lý: BLACKPINK
# [DFS Độ sâu 1] Xử lý: The Album (album c%E1%BB%A7a Blackpink)
# [DFS Độ sâu 2] Xử lý: Mnet Asian Music Award for Album of the Year
# [DFS Độ sâu 3] Xử lý: 2NE1 2nd Mini Album
# [DFS Độ sâu 3] Xử lý: Gi%E1%BA%A3i MAMA cho B%C3%A0i h%C3%A1t c%E1%BB%A7a n%C4%83m
# [DFS Độ sâu 3] Xử lý: Gi%E1%BA%A3i MAMA cho Nh%C3%B3m nh%E1%BA%A1c nam xu%E1%BA%A5t s%E1%BA%AFc nh%E1%BA%A5t
# [DFS Độ sâu 3] Xử lý: Gi%E1%BA%A3i MAMA cho Nh%C3%B3m nh%E1%BA%A1c n%E1%BB%AF xu%E1%BA%A5t s%E1%BA%AFc nh%E1%BA%A5t
# [DFS Độ sâu 2] Xử lý: B%E1%BA%A3n m%E1%BA%ABu:Ch%C3%BA th%C3%ADch ghi ch%C3%BA album
# [DFS Độ sâu 3] Xử lý: B%E1%BA%A3n m%E1%BA%ABu:Ch%C3%BA th%C3%ADch ghi ch%C3%BA album/doc
# [DFS Độ sâu 2] Xử lý: Danh s%C3%A1ch gi%E1%BA%A3i th%C6%B0%E1%BB%9Fng v%C3%A0 %C4%91%E1%BB%81 c%E1%BB%AD c%E1%BB%A7a Blackpink
# [DFS Độ sâu 1] Xử lý: C%C3%A1c b%E1%BA%A3ng x%E1%BA%BFp h%E1%BA%A1ng Billboard
# [DFS Độ sâu 2] Xử lý: Top Heatseekers
# [DFS Độ sâu 3] Xử lý: Independent Albums
# [DFS Độ sâu 3] Xử lý: Canadian Albums Chart
# [DFS Độ sâu 3] Xử lý: Top Country Albums
# [DFS Độ sâu 3] Xử lý: Dance/Electronic Albums
# [DFS Độ sâu 3] Xử lý: European Top 100 Albums
# [DFS Độ sâu 1] Xử lý: Dua Lipa (album)
# [DFS Độ sâu 0] Xử lý: TWICE
# [DFS Độ sâu 1] Xử lý: B%E1%BA%A3ng x%E1%BA%BFp h%E1%BA%A1ng Billboard
# [DFS Độ sâu 0] Xử lý: IU
# [DFS Độ sâu 1] Xử lý: IU (ca s%C4%A9)
# [DFS Độ sâu 2] Xử lý: Ca s%C4%A9
# [DFS Độ sâu 2] Xử lý: Nh%C3%A0 s%C3%A1ng t%C3%A1c ca kh%C3%BAc
# [DFS Độ sâu 3] Xử lý: Nh%E1%BA%A1c s%C4%A9 so%E1%BA%A1n l%E1%BB%9Di b%C3%A0i h%C3%A1t
# [DFS Độ sâu 3] Xử lý: H%E1%BB%99i Nh%E1%BA%A1c s%C4%A9 Vi%E1%BB%87t Nam
# [DFS Độ sâu 3] Xử lý: Nh%C3%A0 so%E1%BA%A1n nh%E1%BA%A1c
# [DFS Độ sâu 3] Xử lý: Ca s%C4%A9 ki%C3%AAm nh%E1%BA%A1c s%C4%A9 s%C3%A1ng t%C3%A1c b%C3%A0i h%C3%A1t
# [DFS Độ sâu 3] Xử lý: Gi%E1%BA%A3i Oscar cho ca kh%C3%BAc g%E1%BB%91c trong phim xu%E1%BA%A5t s%E1%BA%AFc nh%E1%BA%A5t
# [DFS Độ sâu 2] Xử lý: Di%E1%BB%85n vi%C3%AAn
# [DFS Độ sâu 3] Xử lý: Tuy%E1%BB%83n di%E1%BB%85n vi%C3%AAn
# [DFS Độ sâu 3] Xử lý: Di%E1%BB%85n vi%C3%AAn %C4%91i%E1%BB%87n %E1%BA%A3nh
# [DFS Độ sâu 3] Xử lý: Di%E1%BB%85n vi%C3%AAn truy%E1%BB%81n h%C3%ACnh
# [DFS Độ sâu 3] Xử lý: Di%E1%BB%85n vi%C3%AAn %C4%91%C3%B3ng th%E1%BA%BF
# [DFS Độ sâu 3] Xử lý: Di%E1%BB%85n vi%C3%AAn v%C3%B5 thu%E1%BA%ADt
# [DFS Độ sâu 3] Xử lý: Di%E1%BB%85n vi%C3%AAn h%C3%A0i
# [DFS Độ sâu 3] Xử lý: Di%E1%BB%85n vi%C3%AAn l%E1%BB%93ng ti%E1%BA%BFng
# [DFS Độ sâu 3] Xử lý: Di%E1%BB%85n vi%C3%AAn m%C3%BAa
# [DFS Độ sâu 3] Xử lý: Th%E1%BB%83 lo%E1%BA%A1i:Danh s%C3%A1ch di%E1%BB%85n vi%C3%AAn
# [DFS Độ sâu 3] Xử lý: Di%E1%BB%85n vi%C3%AAn ch%C3%ADnh
# [DFS Độ sâu 2] Xử lý: Growing Up (album c%E1%BB%A7a IU)
# [DFS Độ sâu 3] Xử lý: Ca s%C4%A9-nh%E1%BA%A1c s%C4%A9
# [DFS Độ sâu 3] Xử lý: Danh s%C3%A1ch gi%E1%BA%A3i th%C6%B0%E1%BB%9Fng v%C3%A0 %C4%91%E1%BB%81 c%E1%BB%AD c%E1%BB%A7a IU
# [DFS Độ sâu 0] Xử lý: EXO
# [DFS Độ sâu 1] Xử lý: World Albums Chart
#
# Thống kê DFS theo độ sâu: {0: 5, 1: 9, 2: 18, 3: 62}
#
# ======================================================================
# TÓM TẮT MẠNG LƯỚI
# ======================================================================
# Tổng nodes: 94
# Tổng edges: 448
# Mật độ: 4.77
#
# Top 5 node có liên kết nhiều nhất:
#   - BTS: 10 liên kết
#   - Nh%C3%B3m nh%E1%BA%A1c nam: 10 liên kết
#   - Nh%C3%B3m nh%E1%BA%A1c n%E1%BB%AF: 10 liên kết
#   - Gaon Album Chart: 10 liên kết
#   - Danh s%C3%A1ch nh%C3%B3m nh%E1%BA%A1c n%E1%BB%AF H%C3%A0n Qu%E1%BB%91c: 10 liên kết
#
# Dữ liệu đã lưu vào korean_artists_graph_2.json
# Tổng nodes: 94
# Tổng edges: 448

# %%
# Out:
# ======================================================================
# HỆ THỐNG DUYỆT TẬP HẠT GIỐNG - CA SĨ/NHẠC Sĩ HÀN QUỐC
# ======================================================================
#
# Tập hạt giống: ['BTS', 'BLACKPINK', 'TWICE', 'IU', 'EXO']
# Số lượng hạt giống: 5
#
# Chọn thuật toán duyệt:
# 1. BFS - Breadth-First Search
# 2. DFS - Depth-First Search
# 3. Priority-based Expansion
#
# Nhập lựa chọn (1/2/3): 1
#
# ======================================================================
# THUẬT TOÁN: BFS (Breadth-First Search)
# ======================================================================
# [BFS Tầng 0] Xử lý: BTS
# [BFS Tầng 0] Xử lý: BLACKPINK
# [BFS Tầng 0] Xử lý: TWICE
# [BFS Tầng 0] Xử lý: IU
# [BFS Tầng 0] Xử lý: EXO
# [BFS Tầng 1] Xử lý: Nh%C3%B3m nh%E1%BA%A1c nam
# [BFS Tầng 1] Xử lý: Danh s%C3%A1ch album b%C3%A1n ch%E1%BA%A1y nh%E1%BA%A5t t%E1%BA%A1i H%C3%A0n Qu%E1%BB%91c
# [BFS Tầng 1] Xử lý: Danh s%C3%A1ch gi%E1%BA%A3i th%C6%B0%E1%BB%9Fng v%C3%A0 %C4%91%E1%BB%81 c%E1%BB%AD c%E1%BB%A7a BTS
# [BFS Tầng 1] Xử lý: %C4%90%C4%A9a %C4%91%C6%A1n
# [BFS Tầng 1] Xử lý: %C4%90%C4%A9a m%E1%BB%9F r%E1%BB%99ng
# [BFS Tầng 1] Xử lý: Gaon Album Chart
# [BFS Tầng 1] Xử lý: Oricon Albums Chart
# [BFS Tầng 1] Xử lý: %C4%90%C6%A1n v%E1%BB%8B album t%C6%B0%C6%A1ng %C4%91%C6%B0%C6%A1ng
# [BFS Tầng 1] Xử lý: UK Albums Chart
# [BFS Tầng 1] Xử lý: Album t%E1%BB%95ng h%E1%BB%A3p
# [BFS Tầng 1] Xử lý: Gi%E1%BA%A3i Grammy cho Tr%C3%ACnh di%E1%BB%85n song t%E1%BA%A5u ho%E1%BA%B7c nh%C3%B3m nh%E1%BA%A1c pop xu%E1%BA%A5t s%E1%BA%AFc nh%E1%BA%A5t
# [BFS Tầng 1] Xử lý: The Album (album c%E1%BB%A7a Blackpink)
# [BFS Tầng 1] Xử lý: Circle Album Chart
# [BFS Tầng 1] Xử lý: C%C3%A1c b%E1%BA%A3ng x%E1%BA%BFp h%E1%BA%A1ng Billboard
# [BFS Tầng 1] Xử lý: Dua Lipa (album)
# [BFS Tầng 1] Xử lý: Danh s%C3%A1ch gi%E1%BA%A3i th%C6%B0%E1%BB%9Fng v%C3%A0 %C4%91%E1%BB%81 c%E1%BB%AD c%E1%BB%A7a Blackpink
# [BFS Tầng 1] Xử lý: Nh%C3%B3m nh%E1%BA%A1c n%E1%BB%AF
# [BFS Tầng 1] Xử lý: B%E1%BA%A3ng x%E1%BA%BFp h%E1%BA%A1ng Billboard
# [BFS Tầng 1] Xử lý: Album ph%C3%B2ng thu
# [BFS Tầng 1] Xử lý: Top Heatseekers
# [BFS Tầng 1] Xử lý: Album t%C3%A1i ph%C3%A1t h%C3%A0nh
# [BFS Tầng 1] Xử lý: Mini-album
# [BFS Tầng 1] Xử lý: Gi%E1%BA%A3i th%C6%B0%E1%BB%9Fng %C3%82m nh%E1%BA%A1c Seoul
# [BFS Tầng 1] Xử lý: Danh s%C3%A1ch b%C3%A0i h%C3%A1t thu %C3%A2m b%E1%BB%9Fi Twice
# [BFS Tầng 1] Xử lý: Danh s%C3%A1ch gi%E1%BA%A3i th%C6%B0%E1%BB%9Fng v%C3%A0 %C4%91%E1%BB%81 c%E1%BB%AD c%E1%BB%A7a Twice
# [BFS Tầng 1] Xử lý: What Is Love%3F (EP)
# [BFS Tầng 1] Xử lý: IU (ca s%C4%A9)
# [BFS Tầng 1] Xử lý: World Albums Chart
# [BFS Tầng 1] Xử lý: Independent Albums
# [BFS Tầng 2] Xử lý: Ban nh%E1%BA%A1c
# [BFS Tầng 2] Xử lý: Si%C3%AAu ban nh%E1%BA%A1c
# [BFS Tầng 2] Xử lý: Nh%C3%B3m nh%E1%BA%A1c
# [BFS Tầng 2] Xử lý: Album ch%E1%BB%A7 %C4%91%E1%BB%81
# [BFS Tầng 2] Xử lý: Danh s%C3%A1ch album %C4%91%E1%BA%A1t ch%E1%BB%A9ng nh%E1%BA%ADn t%E1%BA%A1i H%C3%A0n Qu%E1%BB%91c
# [BFS Tầng 2] Xử lý: The Album
# [BFS Tầng 2] Xử lý: The Bodyguard: Original Soundtrack Album
# [BFS Tầng 2] Xử lý: Danh s%C3%A1ch b%C3%A0i h%C3%A1t %C4%91%E1%BA%A1t ch%E1%BB%A9ng nh%E1%BA%ADn t%E1%BA%A1i H%C3%A0n Qu%E1%BB%91c
# [BFS Tầng 2] Xử lý: Gi%E1%BA%A3i th%C6%B0%E1%BB%9Fng %C3%82m nh%E1%BA%A1c M%E1%BB%B9 cho Ban nh%E1%BA%A1c/C%E1%BA%B7p %C4%91%C3%B4i/Nh%C3%B3m nh%E1%BA%A1c Pop/Rock %C4%91%C6%B0%E1%BB%A3c y%C3%AAu th%C3%ADch nh%E1%BA%A5t
# [BFS Tầng 2] Xử lý: Danh s%C3%A1ch album c%E1%BB%A7a BTS
# [BFS Tầng 2] Xử lý: B%C3%A0i h%C3%A1t
# [BFS Tầng 2] Xử lý: Album
# [BFS Tầng 2] Xử lý: Nh%E1%BA%A1c s%C4%A9
# [BFS Tầng 2] Xử lý: Extended play
# [BFS Tầng 2] Xử lý: German Albums Chart
# [BFS Tầng 2] Xử lý: Demo (nh%E1%BA%A1c)
# [BFS Tầng 2] Xử lý: Album tuy%E1%BB%83n t%E1%BA%ADp
# [BFS Tầng 2] Xử lý: Gi%E1%BA%A3i Grammy cho Tr%C3%ACnh di%E1%BB%85n song t%E1%BA%A5u ho%E1%BA%B7c nh%C3%B3m nh%E1%BA%A1c gi%E1%BB%8Dng pop xu%E1%BA%A5t s%E1%BA%AFc nh%E1%BA%A5t
# [BFS Tầng 2] Xử lý: Gi%E1%BA%A3i Grammy cho Tr%C3%ACnh di%E1%BB%85n song t%E1%BA%A5u ho%E1%BA%B7c nh%C3%B3m nh%E1%BA%A1c gi%E1%BB%8Dng rock xu%E1%BA%A5t s%E1%BA%AFc nh%E1%BA%A5t
# [BFS Tầng 2] Xử lý: Gi%E1%BA%A3i Grammy cho album c%E1%BB%A7a n%C4%83m
# [BFS Tầng 2] Xử lý: Gi%E1%BA%A3i Grammy cho b%C3%A0i h%C3%A1t c%E1%BB%A7a n%C4%83m
# [BFS Tầng 2] Xử lý: Gi%E1%BA%A3i Grammy cho album soundtrack nh%E1%BA%A1c n%E1%BB%81n xu%E1%BA%A5t s%E1%BA%AFc nh%E1%BA%A5t cho ph%C6%B0%C6%A1ng ti%E1%BB%87n truy%E1%BB%81n h%C3%ACnh %E1%BA%A3nh
# [BFS Tầng 2] Xử lý: Gi%E1%BA%A3i Grammy cho album soundtrack tuy%E1%BB%83n t%E1%BA%ADp xu%E1%BA%A5t s%E1%BA%AFc nh%E1%BA%A5t cho ph%C6%B0%C6%A1ng ti%E1%BB%87n truy%E1%BB%81n h%C3%ACnh %E1%BA%A3nh
# [BFS Tầng 2] Xử lý: Gi%E1%BA%A3i Grammy cho b%C3%A0i h%C3%A1t xu%E1%BA%A5t s%E1%BA%AFc nh%E1%BA%A5t %C4%91%C6%B0%E1%BB%A3c s%C3%A1ng t%C3%A1c cho ph%C6%B0%C6%A1ng ti%E1%BB%87n truy%E1%BB%81n h%C3%ACnh %E1%BA%A3nh
# [BFS Tầng 2] Xử lý: Gi%E1%BA%A3i Grammy cho album latin pop xu%E1%BA%A5t s%E1%BA%AFc nh%E1%BA%A5t
# [BFS Tầng 2] Xử lý: Gi%E1%BA%A3i Grammy cho album gi%E1%BB%8Dng pop xu%E1%BA%A5t s%E1%BA%AFc nh%E1%BA%A5t
# [BFS Tầng 2] Xử lý: Gi%E1%BA%A3i Grammy cho album nh%E1%BA%A1c dance/%C4%91i%E1%BB%87n t%E1%BB%AD xu%E1%BA%A5t s%E1%BA%AFc nh%E1%BA%A5t
# [BFS Tầng 2] Xử lý: Gi%E1%BA%A3i Grammy cho album R%26B xu%E1%BA%A5t s%E1%BA%AFc nh%E1%BA%A5t
# [BFS Tầng 2] Xử lý: Gi%E1%BA%A3i Grammy cho b%C3%A0i h%C3%A1t R%26B xu%E1%BA%A5t s%E1%BA%AFc nh%E1%BA%A5t
# [BFS Tầng 2] Xử lý: Gi%E1%BA%A3i Grammy cho album nh%E1%BA%A1c alternative xu%E1%BA%A5t s%E1%BA%AFc nh%E1%BA%A5t
# [BFS Tầng 2] Xử lý: Gi%E1%BA%A3i Grammy cho album rock xu%E1%BA%A5t s%E1%BA%AFc nh%E1%BA%A5t
# [BFS Tầng 2] Xử lý: Gi%E1%BA%A3i Grammy cho b%C3%A0i h%C3%A1t rock xu%E1%BA%A5t s%E1%BA%AFc nh%E1%BA%A5t
# [BFS Tầng 2] Xử lý: Mnet Asian Music Award for Album of the Year
# [BFS Tầng 2] Xử lý: B%E1%BA%A3n m%E1%BA%ABu:Ch%C3%BA th%C3%ADch ghi ch%C3%BA album
# [BFS Tầng 2] Xử lý: European Top 100 Albums
# [BFS Tầng 2] Xử lý: Canadian Albums Chart
# [BFS Tầng 2] Xử lý: Top Country Albums
# [BFS Tầng 2] Xử lý: Dance/Electronic Albums
# [BFS Tầng 2] Xử lý: AKB48 Group
# [BFS Tầng 2] Xử lý: Danh s%C3%A1ch nh%C3%B3m nh%E1%BA%A1c n%E1%BB%AF H%C3%A0n Qu%E1%BB%91c
# [BFS Tầng 2] Xử lý: Album hay nh%E1%BA%A5t n%C4%83m c%E1%BB%A7a NME
# [BFS Tầng 2] Xử lý: BTS (nh%C3%B3m nh%E1%BA%A1c)
# [BFS Tầng 2] Xử lý: Twice (nh%C3%B3m nh%E1%BA%A1c)
# [BFS Tầng 2] Xử lý: Ca s%C4%A9
# [BFS Tầng 2] Xử lý: Nh%C3%A0 s%C3%A1ng t%C3%A1c ca kh%C3%BAc
# [BFS Tầng 2] Xử lý: Di%E1%BB%85n vi%C3%AAn
# [BFS Tầng 2] Xử lý: Growing Up (album c%E1%BB%A7a IU)
# [BFS Tầng 2] Xử lý: Gi%E1%BA%A3i th%C6%B0%E1%BB%9Fng %C3%A2m nh%E1%BA%A1c Seoul
# [BFS Tầng 2] Xử lý: Gi%E1%BA%A3i th%C6%B0%E1%BB%9Fng %C3%82m nh%E1%BA%A1c H%C3%A0n Qu%E1%BB%91c
# [BFS Tầng 2] Xử lý: Gi%E1%BA%A3i th%C6%B0%E1%BB%9Fng ngh%E1%BB%87 thu%E1%BA%ADt Baeksang
# [BFS Tầng 3] Xử lý: Danh s%C3%A1ch c%C3%A1c album b%C3%A1n ch%E1%BA%A1y nh%E1%BA%A5t t%E1%BA%A1i H%C3%A0n Qu%E1%BB%91c
# [BFS Tầng 3] Xử lý: Danh s%C3%A1ch c%C3%A1c b%C3%A0i h%C3%A1t %C4%91%E1%BA%A1t ch%E1%BB%A9ng nh%E1%BA%ADn t%E1%BA%A1i H%C3%A0n Qu%E1%BB%91c
# [BFS Tầng 3] Xử lý: Soundtrack
# [BFS Tầng 3] Xử lý: The Preacher%27s Wife: Original Soundtrack Album
# [BFS Tầng 3] Xử lý: Gi%E1%BA%A3i th%C6%B0%E1%BB%9Fng %C3%82m nh%E1%BA%A1c M%E1%BB%B9
# [BFS Tầng 3] Xử lý: Gi%E1%BA%A3i th%C6%B0%E1%BB%9Fng %C3%82m nh%E1%BA%A1c Billboard
# [BFS Tầng 3] Xử lý: Gi%E1%BA%A3i Grammy cho Album c%E1%BB%A7a n%C4%83m
# [BFS Tầng 3] Xử lý: Gi%E1%BA%A3i Oscar cho ca kh%C3%BAc trong phim hay nh%E1%BA%A5t
# [BFS Tầng 3] Xử lý: Danh s%C3%A1ch album b%C3%A1n ch%E1%BA%A1y nh%E1%BA%A5t th%E1%BA%BF gi%E1%BB%9Bi
# [BFS Tầng 3] Xử lý: Danh s%C3%A1ch album qu%C3%A1n qu%C3%A2n n%C4%83m 1992 (M%E1%BB%B9)
# [BFS Tầng 3] Xử lý: Danh s%C3%A1ch album qu%C3%A1n qu%C3%A2n n%C4%83m 1993 (M%E1%BB%B9)
# [BFS Tầng 3] Xử lý: Danh s%C3%A1ch album b%C3%A1n ch%E1%BA%A1y nh%E1%BA%A5t t%E1%BA%A1i M%E1%BB%B9
# [BFS Tầng 3] Xử lý: Danh s%C3%A1ch %C4%91%C4%A9a nh%E1%BA%A1c c%E1%BB%A7a Whitney Houston
# [BFS Tầng 3] Xử lý: One Wish: The Holiday Album
# [BFS Tầng 3] Xử lý: Gi%E1%BA%A3i th%C6%B0%E1%BB%9Fng %C3%82m nh%E1%BA%A1c M%E1%BB%B9 cho Ngh%E1%BB%87 s%C4%A9 c%E1%BB%A7a n%C4%83m
# [BFS Tầng 3] Xử lý: Gi%E1%BA%A3i th%C6%B0%E1%BB%9Fng %C3%82m nh%E1%BA%A1c M%E1%BB%B9 cho Album Pop/Rock %C4%91%C6%B0%E1%BB%A3c y%C3%AAu th%C3%ADch nh%E1%BA%A5t
#
# Thống kê BFS theo tầng: {0: 5, 1: 29, 2: 50, 3: 16}
#
# ======================================================================
# TÓM TẮT MẠNG LƯỚI
# ======================================================================
# Tổng nodes: 100
# Tổng edges: 164
# Mật độ: 1.64
#
# Top 5 node có liên kết nhiều nhất:
#   - Gi%E1%BA%A3i Grammy cho Tr%C3%ACnh di%E1%BB%85n song t%E1%BA%A5u ho%E1%BA%B7c nh%C3%B3m nh%E1%BA%A1c pop xu%E1%BA%A5t s%E1%BA%AFc nh%E1%BA%A5t: 15 liên kết
#   - The Bodyguard: Original Soundtrack Album: 12 liên kết
#   - Danh s%C3%A1ch nh%C3%B3m nh%E1%BA%A1c n%E1%BB%AF H%C3%A0n Qu%E1%BB%91c: 12 liên kết
#   - BTS: 11 liên kết
#   - Di%E1%BB%85n vi%C3%AAn: 11 liên kết
#
# Dữ liệu đã lưu vào korean_artists_graph_1.json
# Tổng nodes: 100
# Tổng edges: 164

# %%
# -*- coding: utf-8 -*-
import requests
from bs4 import BeautifulSoup
import json
from collections import defaultdict, deque
import time
import sys

# Đảm bảo output UTF-8 trên Windows
if sys.platform == 'win32':
    import io
    sys.stdout = io.TextIOWrapper(sys.stdout.buffer, encoding='utf-8')

class WikipediaBFScraper:
    def __init__(self):
        self.base_url = "https://vi.wikipedia.org/wiki/"
        self.session = requests.Session( )
        self.session.headers.update({
            'User-Agent': 'ManusAI/1.0 (Academic K-pop Graph Scraper)'
        })
        self.nodes = {}
        self.edges = []

        # Từ khóa để xác định một trang có liên quan đến chủ đề hay không
        self.topic_keywords = ['ca sĩ', 'nhạc sĩ', 'diễn viên', 'nhóm nhạc', 'k-pop',
                               'album', 'bài hát', 'ost', 'giải thưởng', 'công ty giải trí']

        # Các mẫu để xác định loại quan hệ giữa các node
        self.relation_patterns = {
            'MEMBER_OF': ['thành viên', 'tham gia nhóm'],
            'COLLABORATED_WITH': ['hợp tác', 'cộng tác', 'featuring', 'ft.', 'ft'],
            'PART_OF_ALBUM': ['album', 'bài hát trong', 'đĩa đơn từ'],
            'IN_DRAMA_OR_OST': ['phim', 'tập phim', 'ost', 'nhạc phim'],
            'MANAGED_BY': ['công ty quản lý', 'hãng đĩa', 'agency', 'quản lý bởi'],
            'PRODUCED': ['sản xuất', 'nhà sản xuất', 'producer', 'sáng tác'],
            'WON_AWARD': ['giải thưởng', 'đoạt giải', 'nhận giải', 'chiến thắng'],
            'SUB_UNIT_OF': ['nhóm nhỏ', 'dự án nhóm'],
        }

    def get_page_soup(self, title):
        """Tải và phân tích HTML của một trang Wikipedia."""
        try:
            url = self.base_url + title.replace(" ", "_")
            response = self.session.get(url, timeout=10)
            response.raise_for_status() # Báo lỗi nếu request không thành công
            # Sử dụng BeautifulSoup để phân tích HTML
            return BeautifulSoup(response.content, 'html.parser')
        except requests.exceptions.RequestException as e:
            print(f"  ✗ Lỗi mạng khi truy cập '{title}': {e}")
        return None

    def extract_infobox(self, soup):
        """Trích xuất dữ liệu từ bảng infobox bên phải trang."""
        infobox_data = {}
        infobox_table = soup.find('table', class_='infobox')
        if infobox_table:
            for row in infobox_table.find_all('tr'):
                header = row.find('th')
                data = row.find('td')
                if header and data:
                    key = header.get_text(strip=True)
                    value = data.get_text(strip=True)
                    infobox_data[key] = value
        return infobox_data

    def classify_relation(self, context_text):
        """Phân loại mối quan hệ dựa trên văn bản xung quanh liên kết."""
        context_lower = context_text.lower()
        for rel_type, keywords in self.relation_patterns.items():
            if any(keyword in context_lower for keyword in keywords):
                return rel_type
        return 'RELATED_TO' # Trả về loại mặc định nếu không tìm thấy

    def is_relevant_page(self, title, soup):
        """Kiểm tra xem trang có liên quan đến chủ đề ca sĩ/nhạc sĩ Hàn Quốc không."""
        text_content = soup.get_text().lower()
        # Một trang được coi là liên quan nếu có ít nhất 2 từ khóa chủ đề
        relevance_score = sum(1 for keyword in self.topic_keywords if keyword in text_content)
        return relevance_score >= 2

    def scrape_with_bfs(self, seed_artists, max_nodes=1000):
        """
        Sử dụng thuật toán BFS (Breadth-First Search) để xây dựng mạng lưới.
        - Bắt đầu từ các node hạt giống.
        - Duyệt qua từng "tầng" các node liên quan.
        - Dừng lại khi đạt đủ số lượng node.
        """
        print("\n" + "="*70)
        print("Bắt đầu thu thập dữ liệu bằng thuật toán BFS (Tìm kiếm theo chiều rộng)")
        print("="*70)

        queue = deque([(artist, 0) for artist in seed_artists]) # (tên_node, độ_sâu)
        visited = set(seed_artists)

        while queue and len(self.nodes) < max_nodes:
            current_title, depth = queue.popleft()

            print(f"[Tầng {depth}] Đang xử lý: {current_title} ({len(self.nodes) + 1}/{max_nodes})")

            soup = self.get_page_soup(current_title)
            if not soup:
                continue

            # Chỉ xử lý các trang có liên quan
            if not self.is_relevant_page(current_title, soup):
                print(f"  - Bỏ qua trang không liên quan: {current_title}")
                continue

            infobox = self.extract_infobox(soup)

            # Lưu thông tin node
            self.nodes[current_title] = {
                'label': 'Artist/Group', # Cần cải tiến để phân loại rõ hơn
                'infobox': infobox,
                'url': self.base_url + current_title.replace(" ", "_"),
                'depth': depth
            }

            # Tìm tất cả các liên kết hợp lệ trong phần nội dung
            content_div = soup.find('div', id='mw-content-text')
            if not content_div:
                continue

            for link in content_div.find_all('a', href=True):
                href = link['href']
                if href.startswith('/wiki/') and ':' not in href and '#' not in href:
                    target_title = href.replace('/wiki/', '').replace('_', ' ')

                    if target_title not in visited and len(self.nodes) < max_nodes:
                        visited.add(target_title)
                        queue.append((target_title, depth + 1))

                        # Tạo cạnh với thông tin quan hệ
                        relation_type = self.classify_relation(link.get_text())
                        self.edges.append({
                            'source': current_title,
                            'target': target_title,
                            'type': relation_type,
                            'text': link.get_text(strip=True)
                        })

            time.sleep(0.2) # Tạm dừng một chút để tránh gửi quá nhiều yêu cầu

        print("\n✓ Thu thập dữ liệu hoàn tất!")

    def save_data(self, filename='korean_artists_graph_bfs.json'):
        """Lưu dữ liệu node và cạnh vào file JSON."""
        graph_data = {
            'nodes': self.nodes,
            'edges': self.edges,
            'stats': {
                'node_count': len(self.nodes),
                'edge_count': len(self.edges),
            }
        }
        with open(filename, 'w', encoding='utf-8') as f:
            json.dump(graph_data, f, ensure_ascii=False, indent=2)
        print(f"✓ Dữ liệu đã được lưu vào tệp: {filename}")

# --- PHẦN THỰC THI CHÍNH ---

if __name__ == "__main__":
    # Danh sách 10 node hạt giống bạn đã chọn
    SEED_ARTISTS = [
        "BTS", "Blackpink", "Big Bang (nhóm nhạc)", "Girls' Generation", "EXO",
        "Red Velvet (nhóm nhạc)", "NCT (nhóm nhạc)", "Psy", "IU (ca sĩ)", "Cha Eun-woo"
    ]

    # Số lượng node tối đa cần thu thập (theo yêu cầu là tối thiểu 1000)
    MAX_NODES_TO_COLLECT = 1000

    print("="*70)
    print("CHƯƠNG TRÌNH XÂY DỰNG MẠNG LƯỚI NGHỆ SĨ HÀN QUỐC")
    print(f"Bắt đầu từ {len(SEED_ARTISTS)} node hạt giống, mục tiêu {MAX_NODES_TO_COLLECT} node.")

    scraper = WikipediaBFScraper()
    scraper.scrape_with_bfs(SEED_ARTISTS, max_nodes=MAX_NODES_TO_COLLECT)
    scraper.save_data()

    # In ra một vài thống kê cơ bản
    print("\n--- THỐNG KÊ MẠNG LƯỚI ---")
    print(f"Tổng số node thu thập được: {len(scraper.nodes)}")
    print(f"Tổng số cạnh (mối quan hệ) tìm thấy: {len(scraper.edges)}")
# Out:
# ======================================================================
# CHƯƠNG TRÌNH XÂY DỰNG MẠNG LƯỚI NGHỆ SĨ HÀN QUỐC
# Bắt đầu từ 10 node hạt giống, mục tiêu 1000 node.
#
# ======================================================================
# Bắt đầu thu thập dữ liệu bằng thuật toán BFS (Tìm kiếm theo chiều rộng)
# ======================================================================
# [Tầng 0] Đang xử lý: BTS (1/1000)
# [Tầng 0] Đang xử lý: Blackpink (2/1000)
# [Tầng 0] Đang xử lý: Big Bang (nhóm nhạc) (3/1000)
# [Tầng 0] Đang xử lý: Girls' Generation (4/1000)
# [Tầng 0] Đang xử lý: EXO (5/1000)
# [Tầng 0] Đang xử lý: Red Velvet (nhóm nhạc) (6/1000)
# [Tầng 0] Đang xử lý: NCT (nhóm nhạc) (7/1000)
# [Tầng 0] Đang xử lý: Psy (8/1000)
# [Tầng 0] Đang xử lý: IU (ca sĩ) (9/1000)
# [Tầng 0] Đang xử lý: Cha Eun-woo (10/1000)
# [Tầng 1] Đang xử lý: BTS (%C4%91%E1%BB%8Bnh h%C6%B0%E1%BB%9Bng) (11/1000)
#   - Bỏ qua trang không liên quan: BTS (%C4%91%E1%BB%8Bnh h%C6%B0%E1%BB%9Bng)
# [Tầng 1] Đang xử lý: Nh%C3%A0 Tr%E1%BA%AFng (11/1000)
#   - Bỏ qua trang không liên quan: Nh%C3%A0 Tr%E1%BA%AFng
# [Tầng 1] Đang xử lý: Seoul (11/1000)
# [Tầng 1] Đang xử lý: H%C3%A0n Qu%E1%BB%91c (12/1000)
# [Tầng 1] Đang xử lý: K-pop (13/1000)
# [Tầng 1] Đang xử lý: Nh%E1%BA%A1c pop (14/1000)
# [Tầng 1] Đang xử lý: Hip hop (15/1000)
# [Tầng 1] Đang xử lý: Rhythm and blues (16/1000)
#   - Bỏ qua trang không liên quan: Rhythm and blues
# [Tầng 1] Đang xử lý: Nh%E1%BA%A1c dance %C4%91i%E1%BB%87n t%E1%BB%AD (16/1000)
# [Tầng 1] Đang xử lý: Big Hit Music (17/1000)
# [Tầng 1] Đang xử lý: Pony Canyon (18/1000)
# [Tầng 1] Đang xử lý: Def Jam Recordings (19/1000)
# [Tầng 1] Đang xử lý: Columbia Records (20/1000)
#   - Bỏ qua trang không liên quan: Columbia Records
# [Tầng 1] Đang xử lý: Universal Music Group (20/1000)
# [Tầng 1] Đang xử lý: Geffen Records (21/1000)
# [Tầng 1] Đang xử lý: Kim Seok-jin (22/1000)
# [Tầng 1] Đang xử lý: Suga (rapper) (23/1000)
# [Tầng 1] Đang xử lý: J-Hope (24/1000)
# [Tầng 1] Đang xử lý: RM (rapper) (25/1000)
# [Tầng 1] Đang xử lý: Jimin (ca s%C4%A9, sinh 1995) (26/1000)
# [Tầng 1] Đang xử lý: V (ca s%C4%A9) (27/1000)
# [Tầng 1] Đang xử lý: Jungkook (28/1000)
# [Tầng 1] Đang xử lý: Hangul (29/1000)
#   - Bỏ qua trang không liên quan: Hangul
# [Tầng 1] Đang xử lý: Hanja (29/1000)
#   - Bỏ qua trang không liên quan: Hanja
# [Tầng 1] Đang xử lý: Romaja qu%E1%BB%91c ng%E1%BB%AF (29/1000)
#   - Bỏ qua trang không liên quan: Romaja qu%E1%BB%91c ng%E1%BB%AF
# [Tầng 1] Đang xử lý: McCune%E2%80%93Reischauer (29/1000)
#   - Bỏ qua trang không liên quan: McCune%E2%80%93Reischauer
# [Tầng 1] Đang xử lý: Kanji (29/1000)
#   - Bỏ qua trang không liên quan: Kanji
# [Tầng 1] Đang xử lý: Hiragana (29/1000)
#   - Bỏ qua trang không liên quan: Hiragana
# [Tầng 1] Đang xử lý: H%E1%BB%87 phi%C3%AAn %C3%A2m La-tinh Hepburn (29/1000)
#   - Bỏ qua trang không liên quan: H%E1%BB%87 phi%C3%AAn %C3%A2m La-tinh Hepburn
# [Tầng 1] Đang xử lý: Ti%E1%BA%BFng H%C3%A0n Qu%E1%BB%91c (29/1000)
#   - Bỏ qua trang không liên quan: Ti%E1%BA%BFng H%C3%A0n Qu%E1%BB%91c
# [Tầng 1] Đang xử lý: Nh%C3%B3m nh%E1%BA%A1c nam (29/1000)
# [Tầng 1] Đang xử lý: Tu%E1%BB%95i th%C3%A0nh ni%C3%AAn (30/1000)
#   - Bỏ qua trang không liên quan: Tu%E1%BB%95i th%C3%A0nh ni%C3%AAn
# [Tầng 1] Đang xử lý: 2 Cool 4 Skool (30/1000)
# [Tầng 1] Đang xử lý: Dark %26 Wild (31/1000)
# [Tầng 1] Đang xử lý: Wake Up (album c%E1%BB%A7a BTS) (32/1000)
# [Tầng 1] Đang xử lý: Wings (album c%E1%BB%A7a BTS) (33/1000)
# [Tầng 1] Đang xử lý: L%C3%A0n s%C3%B3ng H%C3%A0n Qu%E1%BB%91c (34/1000)
# [Tầng 1] Đang xử lý: Hi%E1%BB%87p h%E1%BB%99i C%C3%B4ng nghi%E1%BB%87p Ghi %C3%A2m Hoa K%E1%BB%B3 (35/1000)
#   - Bỏ qua trang không liên quan: Hi%E1%BB%87p h%E1%BB%99i C%C3%B4ng nghi%E1%BB%87p Ghi %C3%A2m Hoa K%E1%BB%B3
# [Tầng 1] Đang xử lý: Mic Drop (b%C3%A0i h%C3%A1t) (35/1000)
# [Tầng 1] Đang xử lý: Billboard 200 (36/1000)
# [Tầng 1] Đang xử lý: The Beatles (37/1000)
# [Tầng 1] Đang xử lý: Billboard Hot 100 (38/1000)
# [Tầng 1] Đang xử lý: Billboard Global 200 (39/1000)
# [Tầng 1] Đang xử lý: Dynamite (b%C3%A0i h%C3%A1t c%E1%BB%A7a BTS) (40/1000)
# [Tầng 1] Đang xử lý: Gi%E1%BA%A3i Grammy cho Video %C3%A2m nh%E1%BA%A1c xu%E1%BA%A5t s%E1%BA%AFc nh%E1%BA%A5t (147/1000)
# [Tầng 1] Đang xử lý: Gi%E1%BA%A3i Grammy cho Album c%E1%BB%A7a n%C4%83m (148/1000)
# [Tầng 1] Đang xử lý: Music of the Spheres (album c%E1%BB%A7a Coldplay) (149/1000)
# [Tầng 1] Đang xử lý: Take Two (150/1000)
# [Tầng 1] Đang xử lý: Freddie Mercury (151/1000)
# [Tầng 1] Đang xử lý: Nas (152/1000)
# [Tầng 1] Đang xử lý: Eminem (153/1000)
# [Tầng 1] Đang xử lý: Kanye West (154/1000)
# [Tầng 1] Đang xử lý: Drake (155/1000)
# [Tầng 1] Đang xử lý: Post Malone (156/1000)
# [Tầng 1] Đang xử lý: Charlie Puth (157/1000)
# [Tầng 1] Đang xử lý: Live Aid (158/1000)
# [Tầng 1] Đang xử lý: Epik High (159/1000)
# [Tầng 1] Đang xử lý: Jay-Z (160/1000)
# [Tầng 1] Đang xử lý: The Notorious B.I.G. (161/1000)
# [Tầng 1] Đang xử lý: Demian (162/1000)
#   - Bỏ qua trang không liên quan: Demian
# [Tầng 1] Đang xử lý: Hermann Hesse (162/1000)
# [Tầng 1] Đang xử lý: Zarathustra %C4%91%C3%A3 n%C3%B3i nh%C6%B0 th%E1%BA%BF (163/1000)
#   - Bỏ qua trang không liên quan: Zarathustra %C4%91%C3%A3 n%C3%B3i nh%C6%B0 th%E1%BA%BF
# [Tầng 1] Đang xử lý: Friedrich Nietzsche (163/1000)
#   - Bỏ qua trang không liên quan: Friedrich Nietzsche
# [Tầng 1] Đang xử lý: Phong c%E1%BA%A3nh khi Icarus r%C6%A1i (163/1000)
#   - Bỏ qua trang không liên quan: Phong c%E1%BA%A3nh khi Icarus r%C6%A1i
# [Tầng 1] Đang xử lý: Pieter Bruegel il Vecchio (163/1000)
#   - Bỏ qua trang không liên quan: Pieter Bruegel il Vecchio
# [Tầng 1] Đang xử lý: Murakami Haruki (163/1000)
# [Tầng 1] Đang xử lý: Ursula K. Le Guin (164/1000)
#   - Bỏ qua trang không liên quan: Ursula K. Le Guin
# [Tầng 1] Đang xử lý: Carl Jung (164/1000)
#   - Bỏ qua trang không liên quan: Carl Jung
# [Tầng 1] Đang xử lý: George Orwell (164/1000)
#   - Bỏ qua trang không liên quan: George Orwell
# [Tầng 1] Đang xử lý: Erich Fromm (164/1000)
#   - Bỏ qua trang không liên quan: Erich Fromm
# [Tầng 1] Đang xử lý: Nh%E1%BA%A1c underground (164/1000)
# [Tầng 1] Đang xử lý: Tupac Shakur (165/1000)
# [Tầng 1] Đang xử lý: Remix (166/1000)
# [Tầng 1] Đang xử lý: Synthesizer (167/1000)
#   - Bỏ qua trang không liên quan: Synthesizer
# [Tầng 1] Đang xử lý: Nh%E1%BB%8Bp (167/1000)
#   - Bỏ qua trang không liên quan: Nh%E1%BB%8Bp
# [Tầng 1] Đang xử lý: Electropop (167/1000)
# [Tầng 1] Đang xử lý: Moombahton (168/1000)
#   - Bỏ qua trang không liên quan: Moombahton
# [Tầng 1] Đang xử lý: Pansori (168/1000)
#   - Bỏ qua trang không liên quan: Pansori
# [Tầng 1] Đang xử lý: Rock (168/1000)
# [Tầng 1] Đang xử lý: Tropical house (169/1000)
# [Tầng 1] Đang xử lý: Future bass (170/1000)
# [Tầng 1] Đang xử lý: Nh%E1%BA%A1c pop Latinh (171/1000)
# [Tầng 1] Đang xử lý: Nh%E1%BA%A1c ballad H%C3%A0n Qu%E1%BB%91c (172/1000)
# [Tầng 1] Đang xử lý: Funk (173/1000)
# [Tầng 1] Đang xử lý: Nh%E1%BA%A1c trap (174/1000)
#   - Bỏ qua trang không liên quan: Nh%E1%BA%A1c trap
# [Tầng 1] Đang xử lý: Pop rock (174/1000)
# [Tầng 1] Đang xử lý: Pop rap (175/1000)
# [Tầng 1] Đang xử lý: Disco (176/1000)
# [Tầng 1] Đang xử lý: Neo soul (177/1000)
#   - Bỏ qua trang không liên quan: Neo soul
# [Tầng 1] Đang xử lý: Th%E1%BA%BF h%E1%BB%87 Millennials (177/1000)
#   - Bỏ qua trang không liên quan: Th%E1%BA%BF h%E1%BB%87 Millennials
# [Tầng 1] Đang xử lý: Ch%E1%BB%A7ng t%C3%ADnh (177/1000)
#   - Bỏ qua trang không liên quan: Ch%E1%BB%A7ng t%C3%ADnh
# [Tầng 1] Đang xử lý: Park Geun-hye (177/1000)
#   - Bỏ qua trang không liên quan: Park Geun-hye
# [Tầng 1] Đang xử lý: Mono (mixtape) (177/1000)
# [Tầng 1] Đang xử lý: Not Today (b%C3%A0i h%C3%A1t c%E1%BB%A7a BTS) (178/1000)
# [Tầng 1] Đang xử lý: V%E1%BB%A5 l%E1%BA%ADt ph%C3%A0 Sewol (179/1000)
#   - Bỏ qua trang không liên quan: V%E1%BB%A5 l%E1%BA%ADt ph%C3%A0 Sewol
# [Tầng 1] Đang xử lý: Moon Jae-in (179/1000)
# [Tầng 1] Đang xử lý: %E1%BA%A2nh h%C6%B0%E1%BB%9Fng v%C4%83n h%C3%B3a c%E1%BB%A7a BTS (180/1000)
# [Tầng 1] Đang xử lý: Ng%C3%A2n h%C3%A0ng Trung %C6%B0%C6%A1ng H%C3%A0n Qu%E1%BB%91c (181/1000)
#   - Bỏ qua trang không liên quan: Ng%C3%A2n h%C3%A0ng Trung %C6%B0%C6%A1ng H%C3%A0n Qu%E1%BB%91c
# [Tầng 1] Đang xử lý: Girls%27 Generation (181/1000)
# [Tầng 1] Đang xử lý: Super Junior (182/1000)
# [Tầng 1] Đang xử lý: EXO (nh%C3%B3m nh%E1%BA%A1c) (183/1000)
# [Tầng 1] Đang xử lý: Twice (184/1000)
# [Tầng 1] Đang xử lý: Joseph Nye (185/1000)
#   - Bỏ qua trang không liên quan: Joseph Nye
# [Tầng 1] Đang xử lý: Quy%E1%BB%81n l%E1%BB%B1c m%E1%BB%81m (185/1000)
#   - Bỏ qua trang không liên quan: Quy%E1%BB%81n l%E1%BB%B1c m%E1%BB%81m
# [Tầng 1] Đang xử lý: V%C4%83n h%C3%B3a (185/1000)
#   - Bỏ qua trang không liên quan: V%C4%83n h%C3%B3a
# [Tầng 1] Đang xử lý: Gi%C3%A1 tr%E1%BB%8B quan (185/1000)
#   - Bỏ qua trang không liên quan: Gi%C3%A1 tr%E1%BB%8B quan
# [Tầng 1] Đang xử lý: Ch%C3%ADnh s%C3%A1ch %C4%91%E1%BB%91i ngo%E1%BA%A1i (185/1000)
#   - Bỏ qua trang không liên quan: Ch%C3%ADnh s%C3%A1ch %C4%91%E1%BB%91i ngo%E1%BA%A1i
# [Tầng 1] Đang xử lý: Joe Biden (185/1000)
# [Tầng 1] Đang xử lý: Instagram (186/1000)
# [Tầng 1] Đang xử lý: Ph%C3%A2n bi%E1%BB%87t ch%E1%BB%A7ng t%E1%BB%99c (187/1000)
#   - Bỏ qua trang không liên quan: Ph%C3%A2n bi%E1%BB%87t ch%E1%BB%A7ng t%E1%BB%99c
# [Tầng 1] Đang xử lý: Quy%E1%BB%81n tr%E1%BA%BB em (187/1000)
#   - Bỏ qua trang không liên quan: Quy%E1%BB%81n tr%E1%BA%BB em
# [Tầng 1] Đang xử lý: Bi%E1%BA%BFn %C4%91%E1%BB%95i kh%C3%AD h%E1%BA%ADu (187/1000)
#   - Bỏ qua trang không liên quan: Bi%E1%BA%BFn %C4%91%E1%BB%95i kh%C3%AD h%E1%BA%ADu
# [Tầng 1] Đang xử lý: Puma (th%C6%B0%C6%A1ng hi%E1%BB%87u) (187/1000)
# [Tầng 1] Đang xử lý: Fila (188/1000)
#   - Bỏ qua trang không liên quan: Fila
# [Tầng 1] Đang xử lý: LG Electronics (188/1000)
# [Tầng 1] Đang xử lý: Xe th%E1%BB%83 thao %C4%91a d%E1%BB%A5ng (189/1000)
#   - Bỏ qua trang không liên quan: Xe th%E1%BB%83 thao %C4%91a d%E1%BB%A5ng
# [Tầng 1] Đang xử lý: Hyundai Motor Group (189/1000)
#   - Bỏ qua trang không liên quan: Hyundai Motor Group
# [Tầng 1] Đang xử lý: Xe hydro (189/1000)
#   - Bỏ qua trang không liên quan: Xe hydro
# [Tầng 1] Đang xử lý: Gi%E1%BA%A3m thi%E1%BB%83u bi%E1%BA%BFn %C4%91%E1%BB%95i kh%C3%AD h%E1%BA%ADu (189/1000)
#   - Bỏ qua trang không liên quan: Gi%E1%BA%A3m thi%E1%BB%83u bi%E1%BA%BFn %C4%91%E1%BB%95i kh%C3%AD h%E1%BA%ADu
# [Tầng 1] Đang xử lý: Samsung Electronics (189/1000)
#   - Bỏ qua trang không liên quan: Samsung Electronics
# [Tầng 1] Đang xử lý: Samsung Galaxy S20 (189/1000)
#   - Bỏ qua trang không liên quan: Samsung Galaxy S20
# [Tầng 1] Đang xử lý: Samsung Gear (189/1000)
#   - Bỏ qua trang không liên quan: Samsung Gear
# [Tầng 1] Đang xử lý: Dior (189/1000)
# [Tầng 1] Đang xử lý: Stade de France (190/1000)
# [Tầng 1] Đang xử lý: Louis Vuitton (191/1000)
#   - Bỏ qua trang không liên quan: Louis Vuitton
# [Tầng 1] Đang xử lý: Ho%E1%BA%A1t %C4%91%E1%BB%99ng t%E1%BB%AB thi%E1%BB%87n c%E1%BB%A7a BTS (191/1000)
# [Tầng 1] Đang xử lý: Vi%E1%BB%87n tr%E1%BB%A3 nh%C3%A2n %C4%91%E1%BA%A1o (192/1000)
#   - Bỏ qua trang không liên quan: Vi%E1%BB%87n tr%E1%BB%A3 nh%C3%A2n %C4%91%E1%BA%A1o
# [Tầng 1] Đang xử lý: Gi%E1%BA%A3i th%C6%B0%E1%BB%9Fng %C3%82m nh%E1%BA%A1c M%E1%BB%B9 cho Ban nh%E1%BA%A1c/C%E1%BA%B7p %C4%91%C3%B4i/Nh%C3%B3m nh%E1%BA%A1c Pop/Rock %C4%91%C6%B0%E1%BB%A3c y%C3%AAu th%C3%ADch nh%E1%BA%A5t (192/1000)
# [Tầng 1] Đang xử lý: Gi%E1%BA%A3i Brit (193/1000)
# [Tầng 1] Đang xử lý: Japan Gold Disc Awards (194/1000)
# [Tầng 1] Đang xử lý: Gi%E1%BA%A3i MAMA (195/1000)
# [Tầng 1] Đang xử lý: T%E1%BB%AB H%C3%A1n-Vi%E1%BB%87t (196/1000)
#   - Bỏ qua trang không liên quan: T%E1%BB%AB H%C3%A1n-Vi%E1%BB%87t
# [Tầng 1] Đang xử lý: Gwacheon (196/1000)
#   - Bỏ qua trang không liên quan: Gwacheon
# [Tầng 1] Đang xử lý: Gyeonggi (196/1000)
#   - Bỏ qua trang không liên quan: Gyeonggi
# [Tầng 1] Đang xử lý: Daegu (196/1000)
# [Tầng 1] Đang xử lý: Qu%E1%BA%ADn B%E1%BA%AFc, Gwangju (197/1000)
#   - Bỏ qua trang không liên quan: Qu%E1%BA%ADn B%E1%BA%AFc, Gwangju
# [Tầng 1] Đang xử lý: Gwangju (197/1000)
#   - Bỏ qua trang không liên quan: Gwangju
# [Tầng 1] Đang xử lý: Dongjak-gu (197/1000)
#   - Bỏ qua trang không liên quan: Dongjak-gu
# [Tầng 1] Đang xử lý: Khu Geumjeong, Busan (197/1000)
#   - Bỏ qua trang không liên quan: Khu Geumjeong, Busan
# [Tầng 1] Đang xử lý: Khu B%E1%BA%AFc, Busan (197/1000)
#   - Bỏ qua trang không liên quan: Khu B%E1%BA%AFc, Busan
# [Tầng 1] Đang xử lý: Danh s%C3%A1ch album c%E1%BB%A7a BTS (197/1000)
# [Tầng 1] Đang xử lý: Danh s%C3%A1ch %C4%91%C4%A9a %C4%91%C6%A1n c%E1%BB%A7a BTS (198/1000)
# [Tầng 1] Đang xử lý: Danh s%C3%A1ch video c%E1%BB%A7a BTS (199/1000)
# [Tầng 1] Đang xử lý: Love Yourself in Seoul (200/1000)
# [Tầng 1] Đang xử lý: BTS In the Soop (201/1000)
# [Tầng 1] Đang xử lý: Danh s%C3%A1ch bu%E1%BB%95i bi%E1%BB%83u di%E1%BB%85n tr%E1%BB%B1c ti%E1%BA%BFp c%E1%BB%A7a BTS (202/1000)
# [Tầng 1] Đang xử lý: Universal Music Japan (203/1000)
# [Tầng 1] Đang xử lý: The New York Times (204/1000)
#   - Bỏ qua trang không liên quan: The New York Times
# [Tầng 1] Đang xử lý: Behance (204/1000)
#   - Bỏ qua trang không liên quan: Behance
# [Tầng 1] Đang xử lý: Gaon Music Chart (204/1000)
# [Tầng 1] Đang xử lý: The Chosun Ilbo (205/1000)
#   - Bỏ qua trang không liên quan: The Chosun Ilbo
# [Tầng 1] Đang xử lý: Melon (d%E1%BB%8Bch v%E1%BB%A5 %C3%A2m nh%E1%BA%A1c tr%E1%BB%B1c tuy%E1%BA%BFn) (205/1000)
# [Tầng 1] Đang xử lý: Seoul Music Awards (206/1000)
# [Tầng 1] Đang xử lý: Los Angeles Times (207/1000)
#   - Bỏ qua trang không liên quan: Los Angeles Times
# [Tầng 1] Đang xử lý: Oricon (207/1000)
# [Tầng 1] Đang xử lý: Mnet (k%C3%AAnh truy%E1%BB%81n h%C3%ACnh) (208/1000)
# [Tầng 1] Đang xử lý: Billboard Japan (209/1000)
# [Tầng 1] Đang xử lý: Th%C3%B4ng t%E1%BA%A5n x%C3%A3 Yonhap (210/1000)
#   - Bỏ qua trang không liên quan: Th%C3%B4ng t%E1%BA%A5n x%C3%A3 Yonhap
# [Tầng 1] Đang xử lý: CNN (210/1000)
#   - Bỏ qua trang không liên quan: CNN
# [Tầng 1] Đang xử lý: CNBC (210/1000)
#   - Bỏ qua trang không liên quan: CNBC
# [Tầng 1] Đang xử lý: Naver (210/1000)
#   - Bỏ qua trang không liên quan: Naver
# [Tầng 1] Đang xử lý: Rolling Stone (210/1000)
#   - Bỏ qua trang không liên quan: Rolling Stone
# [Tầng 1] Đang xử lý: Official Charts Company (210/1000)
#   - Bỏ qua trang không liên quan: Official Charts Company
# [Tầng 1] Đang xử lý: Huffington Post (210/1000)
# [Tầng 1] Đang xử lý: MSN (211/1000)
#   - Bỏ qua trang không liên quan: MSN
# [Tầng 1] Đang xử lý: USA Today (211/1000)
#   - Bỏ qua trang không liên quan: USA Today
# [Tầng 1] Đang xử lý: The Guardian (211/1000)
#   - Bỏ qua trang không liên quan: The Guardian
# [Tầng 1] Đang xử lý: Tu%E1%BB%95i Tr%E1%BA%BB (b%C3%A1o) (211/1000)
# [Tầng 1] Đang xử lý: Bloomberg Markets (212/1000)
#   - Bỏ qua trang không liên quan: Bloomberg Markets
# [Tầng 1] Đang xử lý: Variety (t%E1%BA%A1p ch%C3%AD) (212/1000)
#   - Bỏ qua trang không liên quan: Variety (t%E1%BA%A1p ch%C3%AD)
# [Tầng 1] Đang xử lý: BBC News (212/1000)
#   - Bỏ qua trang không liên quan: BBC News
# [Tầng 1] Đang xử lý: The Dong-a Ilbo (212/1000)
#   - Bỏ qua trang không liên quan: The Dong-a Ilbo
# [Tầng 1] Đang xử lý: British Phonographic Industry (212/1000)
#   - Bỏ qua trang không liên quan: British Phonographic Industry
# [Tầng 1] Đang xử lý: Hankook Ilbo (212/1000)
#   - Bỏ qua trang không liên quan: Hankook Ilbo
# [Tầng 1] Đang xử lý: Pitchfork (trang web) (212/1000)
# [Tầng 1] Đang xử lý: Yonhap News Agency (213/1000)
#   - Bỏ qua trang không liên quan: Yonhap News Agency
# [Tầng 1] Đang xử lý: Metacritic (213/1000)
#   - Bỏ qua trang không liên quan: Metacritic
# [Tầng 1] Đang xử lý: Forbes (213/1000)
# [Tầng 1] Đang xử lý: Variety (magazine) (214/1000)
#   - Bỏ qua trang không liên quan: Variety (magazine)
# [Tầng 1] Đang xử lý: Billboard (magazine) (214/1000)
# [Tầng 1] Đang xử lý: The Korea Herald (215/1000)
#   - Bỏ qua trang không liên quan: The Korea Herald
# [Tầng 1] Đang xử lý: Korea JoongAng Daily (215/1000)
#   - Bỏ qua trang không liên quan: Korea JoongAng Daily
# [Tầng 1] Đang xử lý: The Independent (215/1000)
#   - Bỏ qua trang không liên quan: The Independent
# [Tầng 1] Đang xử lý: NME (215/1000)
# [Tầng 1] Đang xử lý: Associated Press (216/1000)
#   - Bỏ qua trang không liên quan: Associated Press
# [Tầng 1] Đang xử lý: Bloomberg News (216/1000)
#   - Bỏ qua trang không liên quan: Bloomberg News
# [Tầng 1] Đang xử lý: Billboard (t%E1%BA%A1p ch%C3%AD) (216/1000)
# [Tầng 1] Đang xử lý: Reuters (217/1000)
#   - Bỏ qua trang không liên quan: Reuters
# [Tầng 1] Đang xử lý: Entertainment Tonight (217/1000)
#   - Bỏ qua trang không liên quan: Entertainment Tonight
# [Tầng 1] Đang xử lý: BBC (217/1000)
# [Tầng 1] Đang xử lý: Korean Broadcasting System (218/1000)
#   - Bỏ qua trang không liên quan: Korean Broadcasting System
# [Tầng 1] Đang xử lý: Big Hit Entertainment (218/1000)
# [Tầng 1] Đang xử lý: ISBN (219/1000)
#   - Bỏ qua trang không liên quan: ISBN
# [Tầng 1] Đang xử lý: Entertainment Weekly (219/1000)
# [Tầng 1] Đang xử lý: ISSN (220/1000)
#   - Bỏ qua trang không liên quan: ISSN
# [Tầng 1] Đang xử lý: Naver Corporation (220/1000)
# [Tầng 1] Đang xử lý: IFPI (221/1000)
# [Tầng 1] Đang xử lý: Harvard Business Review (222/1000)
#   - Bỏ qua trang không liên quan: Harvard Business Review
# [Tầng 1] Đang xử lý: Foreign Policy (222/1000)
#   - Bỏ qua trang không liên quan: Foreign Policy
# [Tầng 1] Đang xử lý: JSTOR (222/1000)
#   - Bỏ qua trang không liên quan: JSTOR
# [Tầng 1] Đang xử lý: Vogue (t%E1%BA%A1p ch%C3%AD) (222/1000)
# [Tầng 1] Đang xử lý: Doi (223/1000)
#   - Bỏ qua trang không liên quan: Doi
# [Tầng 1] Đang xử lý: S2CID (223/1000)
#   - Bỏ qua trang không liên quan: S2CID
# [Tầng 1] Đang xử lý: HuffPost (223/1000)
# [Tầng 1] Đang xử lý: South China Morning Post (224/1000)
#   - Bỏ qua trang không liên quan: South China Morning Post
# [Tầng 1] Đang xử lý: Cambridge University Press (224/1000)
#   - Bỏ qua trang không liên quan: Cambridge University Press
# [Tầng 1] Đang xử lý: Wikimedia Commons (224/1000)
#   - Bỏ qua trang không liên quan: Wikimedia Commons
# [Tầng 1] Đang xử lý: Jennie (ca s%C4%A9) (523/1000)
# [Tầng 1] Đang xử lý: Ros%C3%A9 (ca s%C4%A9) (524/1000)
# [Tầng 1] Đang xử lý: Lisa (rapper) (525/1000)
# [Tầng 1] Đang xử lý: Vi%E1%BA%BFt hoa t%E1%BA%A5t c%E1%BA%A3 c%C3%A1c ch%E1%BB%AF c%C3%A1i (526/1000)
#   - Bỏ qua trang không liên quan: Vi%E1%BA%BFt hoa t%E1%BA%A5t c%E1%BA%A3 c%C3%A1c ch%E1%BB%AF c%C3%A1i
# [Tầng 1] Đang xử lý: L%C3%A0n s%C3%B3ng Hallyu (526/1000)
# [Tầng 1] Đang xử lý: T%E1%BB%B1 tin (527/1000)
#   - Bỏ qua trang không liên quan: T%E1%BB%B1 tin
# [Tầng 1] Đang xử lý: Square One (album %C4%91%C4%A9a %C4%91%C6%A1n) (527/1000)
# [Tầng 1] Đang xử lý: Whistle (b%C3%A0i h%C3%A1t c%E1%BB%A7a Blackpink) (528/1000)
# [Tầng 1] Đang xử lý: Circle Digital Chart (529/1000)
# [Tầng 1] Đang xử lý: Boombayah (530/1000)
# [Tầng 1] Đang xử lý: Square Two (531/1000)
# [Tầng 1] Đang xử lý: Playing with Fire (b%C3%A0i h%C3%A1t c%E1%BB%A7a Blackpink) (532/1000)
# [Tầng 1] Đang xử lý: Canadian Hot 100 (533/1000)
#   - Bỏ qua trang không liên quan: Canadian Hot 100
# [Tầng 1] Đang xử lý: UK Singles Chart (533/1000)
# [Tầng 1] Đang xử lý: YouTube (534/1000)
# [Tầng 1] Đang xử lý: Kill This Love (b%C3%A0i h%C3%A1t) (535/1000)
# [Tầng 1] Đang xử lý: K%E1%BB%B7 l%E1%BB%A5c Guinness th%E1%BA%BF gi%E1%BB%9Bi (536/1000)
#   - Bỏ qua trang không liên quan: K%E1%BB%B7 l%E1%BB%A5c Guinness th%E1%BA%BF gi%E1%BB%9Bi
# [Tầng 1] Đang xử lý: The Album (album c%E1%BB%A7a Blackpink) (536/1000)
# [Tầng 1] Đang xử lý: Born Pink (537/1000)
# [Tầng 1] Đang xử lý: Pink Venom (538/1000)
# [Tầng 1] Đang xử lý: ARIA Charts (539/1000)
# [Tầng 1] Đang xử lý: Born Pink World Tour (540/1000)
# [Tầng 1] Đang xử lý: Coachella (541/1000)
#   - Bỏ qua trang không liên quan: Coachella
# [Tầng 1] Đang xử lý: Danh s%C3%A1ch nh%E1%BB%AFng k%C3%AAnh %C4%91%C6%B0%E1%BB%A3c %C4%91%C4%83ng k%C3%BD nhi%E1%BB%81u nh%E1%BA%A5t YouTube (541/1000)
# [Tầng 1] Đang xử lý: Danh s%C3%A1ch k%C3%AAnh YouTube c%C3%B3 l%C6%B0%E1%BB%A3t xem nhi%E1%BB%81u nh%E1%BA%A5t (542/1000)
# [Tầng 1] Đang xử lý: Spotify (543/1000)
# [Tầng 1] Đang xử lý: MTV Video Music Awards (544/1000)
# [Tầng 1] Đang xử lý: Hu%C3%A2n ch%C6%B0%C6%A1ng %C4%90%E1%BA%BF qu%E1%BB%91c Anh (545/1000)
#   - Bỏ qua trang không liên quan: Hu%C3%A2n ch%C6%B0%C6%A1ng %C4%90%E1%BA%BF qu%E1%BB%91c Anh
# [Tầng 1] Đang xử lý: T%E1%BB%95ng th%E1%BB%91ng H%C3%A0n Qu%E1%BB%91c (545/1000)
# [Tầng 1] Đang xử lý: Nh%C3%A2n t%E1%BB%91 b%C3%AD %E1%BA%A9n (nh%C6%B0%E1%BB%A3ng quy%E1%BB%81n) (546/1000)
# [Tầng 1] Đang xử lý: Billlie (547/1000)
# [Tầng 1] Đang xử lý: EP (548/1000)
#   - Bỏ qua trang không liên quan: EP
# [Tầng 1] Đang xử lý: One of a Kind (EP) (548/1000)
# [Tầng 1] Đang xử lý: Coup d%27Etat (album c%E1%BB%A7a G-Dragon) (549/1000)
# [Tầng 1] Đang xử lý: Vai di%E1%BB%85n kh%C3%A1ch m%E1%BB%9Di (550/1000)
# [Tầng 1] Đang xử lý: H%E1%BA%ADu tr%C6%B0%E1%BB%9Dng gi%E1%BA%A3i tr%C3%AD (551/1000)
# [Tầng 1] Đang xử lý: Inkigayo (552/1000)
# [Tầng 1] Đang xử lý: Seoul Broadcasting System (553/1000)
#   - Bỏ qua trang không liên quan: Seoul Broadcasting System
# [Tầng 1] Đang xử lý: Stay (b%C3%A0i h%C3%A1t c%E1%BB%A7a Blackpink) (553/1000)
# [Tầng 1] Đang xử lý: M Countdown (554/1000)
# [Tầng 1] Đang xử lý: Asia Artist Awards (555/1000)
# [Tầng 1] Đang xử lý: Circle Chart Music Awards (556/1000)
# [Tầng 1] Đang xử lý: As If It%27s Your Last (557/1000)
# [Tầng 1] Đang xử lý: Fandom (558/1000)
# [Tầng 1] Đang xử lý: Bubbling Under Hot 100 (559/1000)
# [Tầng 1] Đang xử lý: Nippon Budokan (560/1000)
# [Tầng 1] Đang xử lý: Blackpink (EP) (561/1000)
# ...
# [Tầng 1] Đang xử lý: B%C3%A0i h%C3%A1t tr%E1%BB%A9 danh (785/1000)
#   - Bỏ qua trang không liên quan: B%C3%A0i h%C3%A1t tr%E1%BB%A9 danh
# [Tầng 1] Đang xử lý: Danh s%C3%A1ch %C4%91%C4%A9a nh%E1%BA%A1c c%E1%BB%A7a Big Bang (785/1000)
# [Tầng 1] Đang xử lý: Made Series (786/1000)
# [Tầng 1] Đang xử lý: Danh s%C3%A1ch c%C3%A1c chuy%E1%BA%BFn l%C6%B0u di%E1%BB%85n c%E1%BB%A7a Big Bang (787/1000)
# [Tầng 1] Đang xử lý: Danh s%C3%A1ch c%C3%A1c chuy%E1%BA%BFn l%C6%B0u di%E1%BB%85n solo c%E1%BB%A7a Big Bang (788/1000)
# [Tầng 1] Đang xử lý: Japan Dome Tour (789/1000)
# [Tầng 1] Đang xử lý: Wayback Machine (790/1000)
#   - Bỏ qua trang không liên quan: Wayback Machine
# [Tầng 1] Đang xử lý: Facebook (790/1000)
# [Tầng 1] Đang xử lý: Avex Trax (791/1000)
#   - Bỏ qua trang không liên quan: Avex Trax
# [Tầng 1] Đang xử lý: TheGuardian.com (791/1000)
#   - Bỏ qua trang không liên quan: TheGuardian.com
# [Tầng 1] Đang xử lý: Big Bang (ban nh%E1%BA%A1c) (791/1000)
# [Tầng 1] Đang xử lý: The Best of Big Bang 2006-2014 (792/1000)
# [Tầng 1] Đang xử lý: MADE World Tour (793/1000)
# [Tầng 1] Đang xử lý: Haru Haru (794/1000)
# [Tầng 1] Đang xử lý: Danh s%C3%A1ch %C4%91%C4%A9a nh%E1%BA%A1c c%E1%BB%A7a G-Dragon (795/1000)
# [Tầng 1] Đang xử lý: GD %26 TOP (album) (796/1000)
# [Tầng 1] Đang xử lý: Solar (album c%E1%BB%A7a Taeyang) (797/1000)
# [Tầng 1] Đang xử lý: Hot (EP) (798/1000)
# [Tầng 1] Đang xử lý: Family Outing (799/1000)
#   - Bỏ qua trang không liên quan: Family Outing
# [Tầng 1] Đang xử lý: Girls%27 Generation (%C4%91%E1%BB%8Bnh h%C6%B0%E1%BB%9Bng) (799/1000)
# [Tầng 1] Đang xử lý: Sooyoung (800/1000)
# [Tầng 1] Đang xử lý: Yoona (801/1000)
# [Tầng 1] Đang xử lý: Sunny (ca s%C4%A9) (802/1000)
# [Tầng 1] Đang xử lý: Hyoyeon (803/1000)
# [Tầng 1] Đang xử lý: Seohyun (804/1000)
# [Tầng 1] Đang xử lý: Taeyeon (805/1000)
# [Tầng 1] Đang xử lý: Kwon Yuri (806/1000)
# [Tầng 1] Đang xử lý: Tiffany Young (807/1000)
# [Tầng 1] Đang xử lý: Dance-pop (808/1000)
# [Tầng 1] Đang xử lý: Bubblegum pop (809/1000)
# [Tầng 1] Đang xử lý: Genie Music (810/1000)
# [Tầng 1] Đang xử lý: EMI Records Japan (811/1000)
#   - Bỏ qua trang không liên quan: EMI Records Japan
# [Tầng 1] Đang xử lý: Hoa K%E1%BB%B3 (811/1000)
# [Tầng 1] Đang xử lý: Choi Sooyoung (812/1000)
# [Tầng 1] Đang xử lý: Jessica Jung (813/1000)
# [Tầng 1] Đang xử lý: Nh%C3%B3m nh%E1%BA%A1c n%E1%BB%AF (814/1000)
# [Tầng 1] Đang xử lý: SM Entertainment (815/1000)
# [Tầng 1] Đang xử lý: Tiffany (ca s%C4%A9 H%C3%A0n Qu%E1%BB%91c) (816/1000)
# [Tầng 1] Đang xử lý: Kim Hyo-yeon (817/1000)
# [Tầng 1] Đang xử lý: Choi Soo-young (818/1000)
# [Tầng 1] Đang xử lý: Into the New World (b%C3%A0i h%C3%A1t) (819/1000)
# [Tầng 1] Đang xử lý: Girls%27 Generation (album 2007) (820/1000)
# [Tầng 1] Đang xử lý: Tell Me Your Wish (Genie) (b%C3%A0i h%C3%A1t) (821/1000)
# [Tầng 1] Đang xử lý: Oh! (b%C3%A0i h%C3%A1t c%E1%BB%A7a Girls%27 Generation) (822/1000)
# [Tầng 1] Đang xử lý: Run Devil Run (b%C3%A0i h%C3%A1t c%E1%BB%A7a Girls%27 Generation) (823/1000)
# [Tầng 1] Đang xử lý: Girls%27 Generation (album 2011) (824/1000)
# [Tầng 1] Đang xử lý: Hi%E1%BB%87p h%E1%BB%99i C%C3%B4ng nghi%E1%BB%87p Ghi %C3%A2m Nh%E1%BA%ADt B%E1%BA%A3n (825/1000)
# [Tầng 1] Đang xử lý: The Boys (album c%E1%BB%A7a Girls%27 Generation) (826/1000)
# [Tầng 1] Đang xử lý: I Got a Boy (827/1000)
# [Tầng 1] Đang xử lý: I Got a Boy (b%C3%A0i h%C3%A1t) (828/1000)
# [Tầng 1] Đang xử lý: Lion Heart (album) (829/1000)
# [Tầng 1] Đang xử lý: Holiday Night (830/1000)
# [Tầng 1] Đang xử lý: Forever 1 (831/1000)
# [Tầng 1] Đang xử lý: R%26B %C4%91%C6%B0%C6%A1ng %C4%91%E1%BA%A1i (832/1000)
# [Tầng 1] Đang xử lý: Danh s%C3%A1ch gi%E1%BA%A3i th%C6%B0%E1%BB%9Fng v%C3%A0 %C4%91%E1%BB%81 c%E1%BB%AD c%E1%BB%A7a Girls%27 Generation (833/1000)
# [Tầng 1] Đang xử lý: Girls%27 Generation (b%C3%A0i h%C3%A1t) (834/1000)
# [Tầng 1] Đang xử lý: Lee Seung-chul (835/1000)
# [Tầng 1] Đang xử lý: S%C3%A2n v%E1%BA%ADn %C4%91%E1%BB%99ng Rajamangala (836/1000)
#   - Bỏ qua trang không liên quan: S%C3%A2n v%E1%BA%ADn %C4%91%E1%BB%99ng Rajamangala
# [Tầng 1] Đang xử lý: Bangkok (836/1000)
#   - Bỏ qua trang không liên quan: Bangkok
# [Tầng 1] Đang xử lý: The Music Trend (836/1000)
# [Tầng 1] Đang xử lý: Jamsil Arena (837/1000)
#   - Bỏ qua trang không liên quan: Jamsil Arena
# [Tầng 1] Đang xử lý: Music Bank (TV Series) (837/1000)
# [Tầng 1] Đang xử lý: Gee (EP) (838/1000)
# [Tầng 1] Đang xử lý: Show! Music Core (839/1000)
# [Tầng 1] Đang xử lý: Tell Me Your Wish (Genie) (840/1000)
# [Tầng 1] Đang xử lý: Into the New World (chuy%E1%BA%BFn l%C6%B0u di%E1%BB%85n) (841/1000)
# [Tầng 1] Đang xử lý: Th%C6%B0%E1%BB%A3ng H%E1%BA%A3i (842/1000)
#   - Bỏ qua trang không liên quan: Th%C6%B0%E1%BB%A3ng H%E1%BA%A3i
# [Tầng 1] Đang xử lý: %C4%90%C3%A0i B%E1%BA%AFc (842/1000)
# [Tầng 1] Đang xử lý: Oh! (album) (843/1000)
# [Tầng 1] Đang xử lý: 2010 (844/1000)
# [Tầng 1] Đang xử lý: %C4%90%C3%A0i Loan (845/1000)
# [Tầng 1] Đang xử lý: Run Devil Run (b%C3%A0i h%C3%A1t) (846/1000)
# [Tầng 1] Đang xử lý: Paris (847/1000)
# [Tầng 1] Đang xử lý: Tokyo (848/1000)
# [Tầng 1] Đang xử lý: Ti%E1%BA%BFng H%C3%A0n (849/1000)
#   - Bỏ qua trang không liên quan: Ti%E1%BA%BFng H%C3%A0n
# [Tầng 1] Đang xử lý: Golden Disk Awards (849/1000)
# [Tầng 1] Đang xử lý: Hoot (EP) (850/1000)
# [Tầng 1] Đang xử lý: Suwon (909/1000)
#   - Bỏ qua trang không liên quan: Suwon
# [Tầng 1] Đang xử lý: Got the Beat (909/1000)
# [Tầng 1] Đang xử lý: Beyond LIVE (910/1000)
# [Tầng 1] Đang xử lý: Jeolla B%E1%BA%AFc (911/1000)
#   - Bỏ qua trang không liên quan: Jeolla B%E1%BA%AFc
# [Tầng 1] Đang xử lý: San Francisco (911/1000)
# [Tầng 1] Đang xử lý: Namdong, Incheon (912/1000)
#   - Bỏ qua trang không liên quan: Namdong, Incheon
# [Tầng 1] Đang xử lý: Deogyang-gu (912/1000)
#   - Bỏ qua trang không liên quan: Deogyang-gu
# [Tầng 1] Đang xử lý: Geumcheon-gu (912/1000)
#   - Bỏ qua trang không liên quan: Geumcheon-gu
# [Tầng 1] Đang xử lý: Teen pop (912/1000)
# [Tầng 1] Đang xử lý: Oh! (b%C3%A0i h%C3%A1t) (913/1000)
# [Tầng 1] Đang xử lý: Hoot (b%C3%A0i h%C3%A1t) (914/1000)
# [Tầng 1] Đang xử lý: The Boys (b%C3%A0i h%C3%A1t) (915/1000)
# [Tầng 1] Đang xử lý: Gwon Yuri (916/1000)
# [Tầng 1] Đang xử lý: Hoot (917/1000)
# [Tầng 1] Đang xử lý: The Boys (918/1000)
# [Tầng 1] Đang xử lý: Jazz (919/1000)
# [Tầng 1] Đang xử lý: Swing (920/1000)
#   - Bỏ qua trang không liên quan: Swing
# [Tầng 1] Đang xử lý: Kissing You (b%C3%A0i h%C3%A1t c%E1%BB%A7a Girls%27 Generation) (920/1000)
# [Tầng 1] Đang xử lý: Cool ng%E1%BA%A7u (921/1000)
#   - Bỏ qua trang không liên quan: Cool ng%E1%BA%A7u
# [Tầng 1] Đang xử lý: Harvard University (921/1000)
# [Tầng 1] Đang xử lý: Krystal Jung (922/1000)
# [Tầng 1] Đang xử lý: %C4%90%E1%BB%99ng %C4%91%E1%BA%A5t v%C3%A0 s%C3%B3ng th%E1%BA%A7n T%C5%8Dhoku 2011 (923/1000)
#   - Bỏ qua trang không liên quan: %C4%90%E1%BB%99ng %C4%91%E1%BA%A5t v%C3%A0 s%C3%B3ng th%E1%BA%A7n T%C5%8Dhoku 2011
# [Tầng 1] Đang xử lý: F(x) (ban nh%E1%BA%A1c) (923/1000)
# [Tầng 1] Đang xử lý: Ban Ki-moon (924/1000)
#   - Bỏ qua trang không liên quan: Ban Ki-moon
# [Tầng 1] Đang xử lý: %C4%90%E1%BA%A1i h%E1%BB%8Dc Dongguk (924/1000)
#   - Bỏ qua trang không liên quan: %C4%90%E1%BA%A1i h%E1%BB%8Dc Dongguk
# [Tầng 1] Đang xử lý: Park Hae-jin (924/1000)
# [Tầng 1] Đang xử lý: Sokcho (925/1000)
#   - Bỏ qua trang không liên quan: Sokcho
# [Tầng 1] Đang xử lý: Danh s%C3%A1ch %C4%91%C4%A9a nh%E1%BA%A1c c%E1%BB%A7a Girls%27 Generation (925/1000)
# [Tầng 1] Đang xử lý: Lion Heart (album c%E1%BB%A7a Girls%27 Generation) (926/1000)
# [Tầng 1] Đang xử lý: Gee (927/1000)
# [Tầng 1] Đang xử lý: The 1st Japan Arena Tour (928/1000)
# [Tầng 1] Đang xử lý: Twitter (929/1000)
# [Tầng 1] Đang xử lý: TikTok (930/1000)
# [Tầng 1] Đang xử lý: Danh s%C3%A1ch phim v%C3%A0 ch%C6%B0%C6%A1ng tr%C3%ACnh t%E1%BA%A1p k%E1%BB%B9 c%E1%BB%A7a Girls%27 Generation (931/1000)
# [Tầng 1] Đang xử lý: Danh s%C3%A1ch gi%E1%BA%A3i th%C6%B0%E1%BB%9Fng c%E1%BB%A7a SNSD (932/1000)
# [Tầng 1] Đang xử lý: ITunes Store (933/1000)
# [Tầng 1] Đang xử lý: Apple Inc (934/1000)
# [Tầng 1] Đang xử lý: Apple Inc. (935/1000)
# [Tầng 1] Đang xử lý: VOH (936/1000)
# [Tầng 1] Đang xử lý: B%C3%A1o %C4%91i%E1%BB%87n t%E1%BB%AD VTV (937/1000)
#   - Bỏ qua trang không liên quan: B%C3%A1o %C4%91i%E1%BB%87n t%E1%BB%AD VTV
# [Tầng 1] Đang xử lý: Yahoo! (937/1000)
#   - Bỏ qua trang không liên quan: Yahoo!
# [Tầng 1] Đang xử lý: Love %26 Peace (album c%E1%BB%A7a Girls%27 Generation) (937/1000)
# [Tầng 1] Đang xử lý: Mr.Mr. (EP) (938/1000)
# [Tầng 1] Đang xử lý: Holler (EP) (939/1000)
# [Tầng 1] Đang xử lý: Dear Santa (EP) (940/1000)
# [Tầng 1] Đang xử lý: New Beginning of Girls%27 Generation (941/1000)
# [Tầng 1] Đang xử lý: Girls%27 Generation Asia Tour Into the New World (942/1000)
# [Tầng 1] Đang xử lý: Factory Girl (943/1000)
# [Tầng 1] Đang xử lý: Hello Baby (944/1000)
# [Tầng 1] Đang xử lý: Danh s%C3%A1ch video c%E1%BB%A7a Girls%27 Generation (945/1000)
# [Tầng 1] Đang xử lý: Baby Baby (b%C3%A0i h%C3%A1t c%E1%BB%A7a Girls%27 Generation) (946/1000)
# [Tầng 1] Đang xử lý: Mr. Taxi (947/1000)
# [Tầng 1] Đang xử lý: NCT (nh%C3%B3m nh%E1%BA%A1c) (948/1000)
# [Tầng 1] Đang xử lý: Hearts2Hearts (949/1000)
# [Tầng 1] Đang xử lý: Kangta (950/1000)
# [Tầng 1] Đang xử lý: Zhou Mi (ca s%C4%A9) (951/1000)
# [Tầng 1] Đang xử lý: Kim Ryeo-wook (952/1000)
# [Tầng 1] Đang xử lý: Yesung (953/1000)
# [Tầng 1] Đang xử lý: Im Yoon-ah (954/1000)
# [Tầng 1] Đang xử lý: Kwon Yu-ri (955/1000)
# [Tầng 1] Đang xử lý: Key (ca s%C4%A9) (956/1000)
# [Tầng 1] Đang xử lý: Yunho (957/1000)
# [Tầng 1] Đang xử lý: Lee Sung-min (958/1000)
# [Tầng 1] Đang xử lý: Suho (959/1000)
# [Tầng 1] Đang xử lý: Changmin (960/1000)
#   - Bỏ qua trang không liên quan: Changmin
# [Tầng 1] Đang xử lý: Kai (ca s%C4%A9) (960/1000)
# [Tầng 1] Đang xử lý: Joy (ca s%C4%A9) (961/1000)
# [Tầng 1] Đang xử lý: Choi Min-ho (ca s%C4%A9) (962/1000)
# [Tầng 1] Đang xử lý: Seulgi (963/1000)
# [Tầng 1] Đang xử lý: Taeyong (964/1000)
# [Tầng 1] Đang xử lý: Chanyeol (965/1000)
# [Tầng 1] Đang xử lý: Ten (ca s%C4%A9) (966/1000)
# [Tầng 1] Đang xử lý: Ho%C3%A0ng H%C3%BAc Hi (967/1000)
# [Tầng 1] Đang xử lý: Doyoung (ca s%C4%A9) (968/1000)
# [Tầng 1] Đang xử lý: Jaehyun (969/1000)
# [Tầng 1] Đang xử lý: Yuta Nakamoto (970/1000)
# [Tầng 1] Đang xử lý: Irene (ca s%C4%A9) (971/1000)
# [Tầng 1] Đang xử lý: Super Junior-K.R.Y. (972/1000)
# [Tầng 1] Đang xử lý: EXO-SC (973/1000)
# [Tầng 1] Đang xử lý: Red Velvet %E2%80%93 Irene %26 Seulgi (974/1000)
# [Tầng 1] Đang xử lý: WayV (975/1000)
# [Tầng 1] Đang xử lý: NCT DoJaeJung (976/1000)
# [Tầng 1] Đang xử lý: NCT Wish (977/1000)
# [Tầng 1] Đang xử lý: SM the Ballad (978/1000)
# [Tầng 1] Đang xử lý: SuperM (979/1000)
# [Tầng 1] Đang xử lý: Lina (ca s%C4%A9 H%C3%A0n Qu%E1%BB%91c) (980/1000)
# [Tầng 1] Đang xử lý: Yoo Young-jin (981/1000)
# [Tầng 1] Đang xử lý: Kenzie (982/1000)
# [Tầng 1] Đang xử lý: I AM (phim 2012) (983/1000)
# [Tầng 1] Đang xử lý: Isak N Jiyeon (984/1000)
# [Tầng 1] Đang xử lý: Kim Jae-joong (985/1000)
# [Tầng 1] Đang xử lý: Park Yoo-chun (986/1000)
# [Tầng 1] Đang xử lý: Kim Junsu (987/1000)
# [Tầng 1] Đang xử lý: No Min-woo (988/1000)
# [Tầng 1] Đang xử lý: Han Geng (989/1000)
# [Tầng 1] Đang xử lý: Exo (990/1000)
# [Tầng 1] Đang xử lý: Kris Wu (991/1000)
# [Tầng 1] Đang xử lý: Lu Han (992/1000)
# [Tầng 1] Đang xử lý: Ho%C3%A0ng T%E1%BB%AD Thao (993/1000)
# [Tầng 1] Đang xử lý: Kim Ki-bum (994/1000)
# [Tầng 1] Đang xử lý: Stephanie Kim (995/1000)
# [Tầng 1] Đang xử lý: Go Ara (996/1000)
# [Tầng 1] Đang xử lý: Zhang Liyin (997/1000)
# [Tầng 1] Đang xử lý: Jonghyun (998/1000)
# [Tầng 1] Đang xử lý: Henry Lau (999/1000)
# [Tầng 1] Đang xử lý: TRAX (1000/1000)
#
# ✓ Thu thập dữ liệu hoàn tất!
# ✓ Dữ liệu đã được lưu vào tệp: korean_artists_graph_bfs.json
#
# --- THỐNG KÊ MẠNG LƯỚI ---
# Tổng số node thu thập được: 1000
# Tổng số cạnh (mối quan hệ) tìm thấy: 26276
